# %%
"""
Created on Tue Jul  7 15:01:19 2020
@author: Nick Bohall
"""
# Out:
# '\nCreated on Tue Jul  7 15:01:19 2020\n@author: Nick Bohall\n'

# %%
#packages
import pandas as pd
import numpy as np
import sklearn as sk 
from sklearn.metrics import f1_score, make_scorer, classification_report
pd.options.mode.chained_assignment = None  # default='warn'

# %%
results = pd.read_csv("Z:\\Coding\\Myproj\\NFL\\Data\\spreadspoke_scores_reversed.csv")
results.replace(r'^\s*$', np.nan, regex=True) #replace Blanks with nan
results.drop(['stadium', 'stadium_neutral'], 1, inplace = True) #dropping columns
results.columns = ['date', 'season', 'week', 'playoff', 'homeTeam', 'homeScore', 'awayScore', 'awayTeam',  #Rename columns
              'favorite', 'spread', 'total', 'temp', 'wind', 'humidity', 'detail']

# %%
#This is a modifier for a specific season of the dataset. If the whole dataset is needed, just comment out
year = input('What year are we looking at?: ')
results = results[results['season'] == int(year)]
# Out:
# What year are we looking at?: 2020

# %%
# Setting larger display for Data Frame
pd.set_option('display.max_rows', 500) 
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
dict = {                    #This is a dictionary of all of the teams and their Abbreviations
'Arizona Cardinals':'ARI',
'Atlanta Falcons':'ATL',
'Baltimore Ravens':'BAL',
'Buffalo Bills':'BUF',
'Carolina Panthers':'CAR',
'Chicago Bears':'CHI',
'Cincinnati Bengals':'CIN',
'Cleveland Browns':'CLE',
'Dallas Cowboys':'DAL',
'Denver Broncos':'DEN',
'Detroit Lions':'DET',
'Green Bay Packers':'GB',
'Houston Texans':'HOU',
'Indianapolis Colts':'IND',
'Jacksonville Jaguars':'JAX',
'Kansas City Chiefs':'KC',
'Los Angeles Chargers':'LAC',
'Los Angeles Rams':'LAR',
'Miami Dolphins':'MIA',
'Minnesota Vikings':'MIN',
'New England Patriots':'NE',
'New Orleans Saints':'NO',
'New York Giants':'NYG',
'New York Jets':'NYJ',
'Oakland Raiders':'OAK',
'Philadelphia Eagles':'PHI',
'Pittsburgh Steelers':'PIT',
'Seattle Seahawks':'SEA',
'San Francisco 49ers':'SF',
'Tampa Bay Buccaneers':'TB',
'Tennessee Titans':'TEN',
'Washington Redskins':'WAS',
'Houston Oilers':'TEN',
'Tennessee Oilers':'TEN',
'Los Angeles Raiders':'OAK',
'San Diego Chargers':'LAC',
'St. Louis Rams':'LAR',
'Phoenix Cardinals':'ARI',
'St. Louis Cardinals':'ARI',
'Baltimore Colts':'IND', 
'Boston Patriots':'NE'
}

# %%
#This changes the team name to the abbreviation so for easier reference
results['homeTeam'] = results['homeTeam'].replace(dict)
results['awayTeam'] = results['awayTeam'].replace(dict)

results['total'] = pd.to_numeric(results['total'], errors='coerce')  #This converts values to numeric and NaN for blanks
results['total'] = results['total'].astype(float) # This converts the type to float

# %%
#exploratory

homeWin = results['homeScore'] > results['awayScore']  #Boolean list of home wins
awayWin = results['homeScore'] < results['awayScore']  #Boolean list of away wins

tie = results['homeScore'] == results['awayScore']     #Boolean list of ties

homeFav = (results.homeTeam == results.favorite)  #Boolean list of Home favorites
awayFav = (results.awayTeam == results.favorite)  #Boolean list of Away favorites

pick = (results.favorite == 'PICK')

# %%
# More Explore

homeFavWin = homeWin & homeFav #When the home favorite wins game
awayFavWin = awayWin & awayFav #When the away favorite wins game

homeFavLose = ~homeWin & homeFav #When the home favorite loses game
awayFavLose = ~awayWin & awayFav #When the away favorite loses game

all = (homeFavWin | awayFavWin | homeFavLose | awayFavLose | pick) #combines all of the possibilities

# %%
#Percentages. These give the decimal values of all 4 scenarios of game outcomes where there is a favorite (does not include pickems)

homeFavWinP = homeFavWin.sum() / homeFav.sum()
awayFavWinP = awayFavWin.sum() / awayFav.sum()
homeFavLoseP = homeFavLose.sum() / homeFav.sum()
awayFavLoseP = awayFavLose.sum() / awayFav.sum()
# Out:
# <ipython-input-9-c7fbe9f18df9>:3: RuntimeWarning: invalid value encountered in longlong_scalars
#   homeFavWinP = homeFavWin.sum() / homeFav.sum()
# <ipython-input-9-c7fbe9f18df9>:4: RuntimeWarning: invalid value encountered in longlong_scalars
#   awayFavWinP = awayFavWin.sum() / awayFav.sum()
# <ipython-input-9-c7fbe9f18df9>:5: RuntimeWarning: invalid value encountered in longlong_scalars
#   homeFavLoseP = homeFavLose.sum() / homeFav.sum()
# <ipython-input-9-c7fbe9f18df9>:6: RuntimeWarning: invalid value encountered in longlong_scalars
#   awayFavLoseP = awayFavLose.sum() / awayFav.sum()

# %%
#This fuction just turns the decimals above to percentages for easy reading. Just pass the argument into 'Input'
def percentage(input):
    new = str(round(input * 100, 2)) + ' %'
    return new

# %%
def seasonStats(season, playoff = False): #Needs work
    stats = results.query("schedule_season == @season & schedule_playoff == @playoff")
    print(stats.head())
    print(sum(stats.score_home))
    print(sum(stats.score_away))

# %%
#Counts the number of times each team is favored
favor = results.favorite.value_counts()

# %%
#Beginning the NBA analysis recreation

results['homeWin'] = homeWin
y_true = results['homeWin'].values #this takes the true false column and turns it into a list
n_games = results['homeWin'].count()  #this is the number of games played
n_homewins = results['homeWin'].sum()  #this is the number of Trues in the column (aka home wins)
win_percentage = n_homewins / n_games  #calculating win %
print('Home Win percentage: {0:.1f}%'.format(100 * win_percentage))
# Out:
# Home Win percentage: 52.1%

# %%
y_pred = [1] * len(y_true) #This is for the modeling later
print('Baseline --> F1: {:.4f}'.format(f1_score(y_true, y_pred, pos_label = None, average = 'weighted'))) #This F1 score is the score to beat
# Out:
# Baseline --> F1: 0.3565

# %%
results['homeLastWin'] = False 
results['awayLastWin'] = False

from collections import defaultdict #like a regular dictionary but doesn't bring errors
won_last = defaultdict(int) #defaultdict makes sets everything in the dictionary to a value of 0 initially

for index, row in results.iterrows(): #iterrows is something that iterrates over a df --> Not efficient
    home_team = row['homeTeam'] #This creates a temporary variable that calls on the home team
    away_team = row['awayTeam'] #This creates a temporary variable that calls on the away team
    row['homeLastWin'] = won_last[home_team] #This ammends the homeLastWin row to the defaultdict of each team
    row['awayLastWin'] = won_last[away_team]
    results.loc[index] = row #Not sure
    won_last[home_team] = row['homeWin']  #This looks at if the team won the game and inputs it into the lastwin columns
    won_last[away_team] = not row['homeWin'] #if homeWin = False, then the away team won
    
print(results[['season', 'week', 'homeTeam', 'homeScore', 'awayScore', 'awayTeam', 'favorite', 'spread', 'total', 'homeWin', 'homeLastWin', 'awayLastWin']])
# Out:
#        season        week homeTeam  homeScore  awayScore awayTeam favorite  spread  total  homeWin homeLastWin awayLastWin
# 12411    2019           1      CHI          3         10       GB      CHI    -3.0   46.5    False           0           0
# 12412    2019           1      ARI         27         27      DET      DET    -3.0   45.5    False           0           0
# 12413    2019           1      CAR         27         30      LAR      LAR    -2.0   49.5    False           0           0
# 12414    2019           1      CLE         13         43      TEN      CLE    -5.5   44.0    False           0           0
# 12415    2019           1      DAL         35         17      NYG      DAL    -7.0   44.0     True           0           0
# 12416    2019           1      JAX         26         40       KC       KC    -3.5   49.0    False           0           0
# 12417    2019           1      LAC         30         24      IND      LAC    -6.0   44.5     True           0           0
# 12418    2019           1      MIA         10         59      BAL      BAL    -7.0   40.5    False           0           0
# 12419    2019           1      MIN         28         12      ATL      MIN    -3.5   47.0     True           0           0
# 12420    2019           1       NE         33          3      PIT       NE    -5.5   49.0     True           0           0
# 12421    2019           1      NYJ         16         17      BUF      NYJ    -2.5   41.0    False           0           0
# 12422    2019           1      PHI         32         27      WAS      PHI   -10.0   44.5     True           0           0
# 12423    2019           1      SEA         21         20      CIN      SEA    -9.0   44.0     True           0           0
# 12424    2019           1       TB         17         31       SF       TB    -1.0   51.0    False           0           0
# 12425    2019           1       NO         30         28      HOU       NO    -6.5   51.5     True           0           0
# 12426    2019           1      OAK         24         16      DEN      DEN    -3.0   42.5     True           0           0
# 12427    2019           2      CAR         14         20       TB      CAR    -6.5   48.0    False       False       False
# 12428    2019           2      ATL         24         20      PHI      PHI    -1.0   53.0     True       False        True
# 12429    2019           2      BAL         23         17      ARI      BAL   -13.0   45.5     True        True       False
# 12430    2019           2      CIN         17         41       SF      CIN    -1.0   46.0    False       False        True
# 12431    2019           2      DEN         14         16      CHI      CHI    -3.0   40.5    False       False       False
# 12432    2019           2      DET         13         10      LAC      LAC    -1.0   46.5     True        True        True
# 12433    2019           2       GB         21         16      MIN       GB    -3.0   43.0     True        True        True
# 12434    2019           2      HOU         13         12      JAX      HOU    -7.0   43.0     True       False       False
# 12435    2019           2      LAR         27          9       NO      LAR    -2.0   52.0     True        True        True
# 12436    2019           2      MIA          0         43       NE       NE   -18.0   48.5    False       False        True
# 12437    2019           2      NYG         14         28      BUF      BUF    -1.0   44.5    False       False        True
# 12438    2019           2      OAK         10         28       KC       KC    -7.0   53.0    False        True        True
# 12439    2019           2      PIT         26         28      SEA      PIT    -4.0   47.0    False       False        True
# 12440    2019           2      TEN         17         19      IND      TEN    -3.5   43.5    False        True       False
# 12441    2019           2      WAS         21         31      DAL      DAL    -6.0   46.0    False       False        True
# 12442    2019           2      NYJ          3         23      CLE      CLE    -6.5   45.0    False       False       False
# 12443    2019           3      JAX         20          7      TEN      TEN    -2.0   38.0     True       False       False
# 12444    2019           3      ARI         20         38      CAR      ARI    -2.5   45.5    False       False       False
# 12445    2019           3      BUF         21         17      CIN      BUF    -6.0   43.5     True        True       False
# 12446    2019           3      CLE         13         20      LAR      LAR    -4.0   48.0    False        True        True
# 12447    2019           3      DAL         31          6      MIA      DAL   -21.5   46.5     True        True       False
# 12448    2019           3       GB         27         16      DEN       GB    -7.0   41.5     True        True       False
# 12449    2019           3      IND         27         24      ATL      IND    -1.5   48.0     True        True        True
# 12450    2019           3       KC         33         28      BAL       KC    -5.0   52.0     True        True        True
# 12451    2019           3      LAC         20         27      HOU      LAC    -3.0   49.0    False       False        True
# 12452    2019           3      MIN         34         14      OAK      MIN    -9.0   43.5     True       False       False
# 12453    2019           3       NE         30         14      NYJ       NE   -21.0   43.0     True        True       False
# 12454    2019           3      PHI         24         27      DET      PHI    -4.0   45.0    False       False        True
# 12455    2019           3       SF         24         20      PIT       SF    -6.0   44.5     True        True       False
# 12456    2019           3      SEA         27         33       NO      SEA    -5.0   44.0    False        True       False
# 12457    2019           3       TB         31         32      NYG       TB    -5.0   48.0    False        True       False
# 12458    2019           3      WAS         15         31      CHI      CHI    -5.0   41.0    False       False        True
# 12459    2019           4       GB         27         34      PHI       GB    -3.5   46.5    False        True       False
# 12460    2019           4      ARI         10         27      SEA      SEA    -5.5   48.5    False       False       False
# 12461    2019           4      ATL         10         24      TEN      ATL    -3.5   46.5    False       False       False
# 12462    2019           4      BAL         25         40      CLE      BAL    -7.0   47.5    False       False       False
# 12463    2019           4      BUF         10         16       NE       NE    -7.0   41.5    False        True        True
# 12464    2019           4      CHI         16          6      MIN      CHI    -1.0   38.5     True        True        True
# 12465    2019           4      DEN         24         26      JAX      DEN    -2.5   37.5    False       False        True
# 12466    2019           4      DET         30         34       KC       KC    -7.0   54.5    False        True        True
# 12467    2019           4      HOU         10         16      CAR      HOU    -5.0   47.5    False        True        True
# 12468    2019           4      IND         24         31      OAK      IND    -6.0   46.5    False        True       False
# 12469    2019           4      LAR         40         55       TB      LAR    -9.0   48.5    False        True       False
# 12470    2019           4      MIA         10         30      LAC      LAC   -15.0   43.5    False       False       False
# 12471    2019           4       NO         12         10      DAL      DAL    -2.5   47.0     True        True        True
# 12472    2019           4      NYG         24          3      WAS      NYG    -3.0   48.0     True        True       False
# 12473    2019           4      PIT         27          3      CIN      PIT    -3.5   45.0     True       False       False
# 12474    2019           5      SEA         30         29      LAR      SEA    -1.5   48.5     True        True       False
# 12475    2019           5      CAR         34         27      JAX      CAR    -3.0   40.5     True        True        True
# 12476    2019           5      CIN         23         26      ARI      CIN    -3.0   46.5    False       False       False
# 12477    2019           5      DAL         24         34       GB      DAL    -3.0   46.5    False       False       False
# 12478    2019           5      HOU         53         32      ATL      HOU    -4.0   49.0     True       False       False
# 12479    2019           5       KC         13         19      IND       KC   -10.5   55.5    False        True       False
# 12480    2019           5      LAC         13         20      DEN      LAC    -4.5   45.5    False        True       False
# 12481    2019           5       NO         31         24       TB       NO    -3.0   46.5     True        True        True
# 12482    2019           5      NYG         10         28      MIN      MIN    -5.5   43.5    False        True       False
# 12483    2019           5      OAK         24         21      CHI      CHI    -6.5   39.5     True        True        True
# 12484    2019           5      PHI         31          6      NYJ      PHI   -14.0   43.0     True        True       False
# 12485    2019           5      PIT         23         26      BAL      BAL    -3.0   44.0    False        True       False
# 12486    2019           5      TEN          7         14      BUF      TEN    -3.0   39.5    False        True       False
# 12487    2019           5      WAS          7         33       NE       NE   -16.5   41.5    False       False        True
# 12488    2019           5       SF         31          3      CLE       SF    -4.5   48.0     True        True        True
# 12489    2019           6       NE         35         14      NYG       NE   -16.5   43.0     True        True       False
# 12490    2019           6      ARI         34         33      ATL      ATL    -3.0   52.0     True        True       False
# 12491    2019           6      BAL         23         17      CIN      BAL   -10.5   46.5     True        True       False
# 12492    2019           6      CLE         28         32      SEA      CLE    -1.0   45.5    False       False        True
# 12493    2019           6      DEN         16          0      TEN      DEN    -1.5   41.0     True        True       False
# 12494    2019           6      JAX          6         13       NO      JAX    -2.5   42.5    False       False        True
# 12495    2019           6       KC         24         31      HOU       KC    -3.5   54.5    False       False        True
# 12496    2019           6      LAC         17         24      PIT      LAC    -6.0   42.5    False       False       False
# 12497    2019           6      LAR          7         20       SF      LAR    -3.0   50.0    False       False        True
# 12498    2019           6      MIA         16         17      WAS      WAS    -5.5   42.5    False       False       False
# 12499    2019           6      MIN         38         20      PHI      MIN    -3.5   44.5     True        True        True
# 12500    2019           6      NYJ         24         22      DAL      DAL    -7.0   43.5     True       False       False
# 12501    2019           6       TB         26         37      CAR      CAR    -2.0   47.5    False       False        True
# 12502    2019           6       GB         23         22      DET       GB    -3.5   47.0     True        True       False
# 12503    2019           7      DEN          6         30       KC       KC    -3.0   49.5    False        True       False
# 12504    2019           7      ATL         10         37      LAR      LAR    -3.0   54.5    False       False       False
# 12505    2019           7      BUF         31         21      MIA      BUF   -17.0   42.5     True        True       False
# 12506    2019           7      CHI         25         36       NO      CHI    -4.0   37.0    False       False        True
# 12507    2019           7      CIN         17         27      JAX      JAX    -4.0   44.0    False       False       False
# 12508    2019           7      DAL         37         10      PHI      DAL    -3.0   50.0     True       False       False
# 12509    2019           7      DET         30         42      MIN      MIN    -2.5   43.5    False       False        True
# 12510    2019           7       GB         42         24      OAK       GB    -5.5   47.5     True        True        True
# 12511    2019           7      IND         30         23      HOU      IND    -1.0   46.5     True        True        True
# 12512    2019           7      NYG         21         27      ARI      NYG    -3.5   50.0    False       False        True
# 12513    2019           7      SEA         16         30      BAL      SEA    -3.0   48.5    False        True        True
# 12514    2019           7      TEN         23         20      LAC      TEN    -2.5   42.5     True       False       False
# 12515    2019           7      WAS          0          9       SF       SF   -10.0   39.0    False        True        True
# 12516    2019           7      NYJ          0         33       NE       NE   -10.0   43.0    False        True        True
# 12517    2019           8      MIN         19          9      WAS      MIN   -16.5   42.0     True        True       False
# 12518    2019           8      ATL         20         27      SEA      SEA    -7.5   48.5    False       False       False
# 12519    2019           8      BUF         13         31      PHI      BUF    -1.0   39.5    False        True       False
# 12520    2019           8      CHI         16         17      LAC      CHI    -3.5   41.0    False       False       False
# 12521    2019           8      DET         31         26      NYG      DET    -6.5   49.0     True       False       False
# 12522    2019           8      HOU         27         24      OAK      HOU    -6.0   52.0     True       False       False
# 12523    2019           8      IND         15         13      DEN      IND    -6.0   42.0     True        True       False
# 12524    2019           8      JAX         29         15      NYJ      JAX    -6.5   40.0     True        True       False
# 12525    2019           8       KC         24         31       GB       GB    -5.0   47.5    False        True        True
# 12526    2019           8      LAR         24         10      CIN      LAR   -12.0   48.5     True        True       False
# 12527    2019           8       NE         27         13      CLE       NE   -10.0   43.0     True        True       False
# 12528    2019           8       NO         31          9      ARI       NO   -12.5   48.0     True        True        True
# 12529    2019           8       SF         51         13      CAR       SF    -4.0   40.5     True        True        True
# 12530    2019           8      TEN         27         23       TB      TEN    -2.0   45.5     True        True       False
# 12531    2019           8      PIT         27         14      MIA      PIT   -14.0   44.0     True        True       False
# 12532    2019           9      ARI         25         28       SF       SF   -10.0   43.0    False       False        True
# 12533    2019           9      BAL         37         20       NE       NE    -3.0   44.5     True        True        True
# 12534    2019           9      BUF         24          9      WAS      BUF   -10.5   37.0     True       False       False
# 12535    2019           9      CAR         30         20      TEN      CAR    -3.5   43.0     True       False        True
# 12536    2019           9      DEN         24         19      CLE      CLE    -4.0   39.0     True       False       False
# 12537    2019           9      JAX          3         26      HOU      JAX    -1.0   46.0    False        True        True
# 12538    2019           9       KC         26         23      MIN      MIN    -5.5   45.5     True       False        True
# 12539    2019           9      LAC         26         11       GB       GB    -4.0   50.0     True        True        True
# 12540    2019           9      MIA         26         18      NYJ      NYJ    -3.0   42.5     True       False       False
# 12541    2019           9      OAK         31         24      DET      OAK    -2.5   51.0     True       False        True
# 12542    2019           9      PHI         22         14      CHI      PHI    -5.0   41.0     True        True       False
# 12543    2019           9      PIT         26         24      IND      PIT    -1.0   40.0     True        True        True
# 12544    2019           9      SEA         40         34       TB      SEA    -4.0   51.0     True        True       False
# 12545    2019           9      NYG         18         37      DAL      DAL    -6.5   48.5    False       False        True
# 12546    2019          10      OAK         26         24      LAC      LAC    -1.0   49.0     True        True        True
# 12547    2019          10      CHI         20         13      DET      CHI    -6.0   38.0     True       False       False
# 12548    2019          10      CIN         13         49      BAL      BAL   -10.5   44.0    False       False        True
# 12549    2019          10      CLE         19         16      BUF      CLE    -3.0   42.0     True       False        True
# 12550    2019          10      DAL         24         28      MIN      DAL    -3.0   48.0    False        True       False
# 12551    2019          10       GB         24         16      CAR       GB    -5.0   49.0     True       False        True
# 12552    2019          10      IND         12         16      MIA      IND   -11.0   44.0    False       False        True
# 12553    2019          10       NO          9         26      ATL       NO   -13.5   51.5    False        True       False
# 12554    2019          10      NYJ         34         27      NYG      NYG    -3.0   43.0     True       False       False
# 12555    2019          10      PIT         17         12      LAR      LAR    -4.5   43.5     True        True        True
# 12556    2019          10       TB         30         27      ARI       TB    -5.5   51.5     True       False       False
# 12557    2019          10      TEN         35         32       KC       KC    -6.0   49.0     True       False        True
# 12558    2019          10       SF         24         27      SEA       SF    -6.5   46.5    False        True        True
# 12559    2019          11      CLE         21          7      PIT      CLE    -3.0   41.5     True        True        True
# 12560    2019          11      BAL         41          7      HOU      BAL    -4.5   51.0     True        True        True
# 12561    2019          11      CAR          3         29      ATL      CAR    -4.0   49.0    False       False        True
# 12562    2019          11      DET         27         35      DAL      DAL    -7.0   46.5    False       False       False
# 12563    2019          11      IND         33         13      JAX      IND    -2.5   41.5     True       False       False
# 12564    2019          11      LAR         17          7      CHI      LAR    -5.5   40.0     True       False        True
# 12565    2019          11      MIA         20         37      BUF      BUF    -7.0   41.0    False        True       False
# 12566    2019          11      MIN         27         23      DEN      MIN   -10.0   40.0     True        True        True
# 12567    2019          11      OAK         17         10      CIN      OAK   -13.0   48.0     True        True       False
# 12568    2019          11      PHI         10         17       NE       NE    -4.5   45.0    False        True       False
# 12569    2019          11       SF         36         26      ARI       SF   -10.0   44.0     True       False       False
# 12570    2019          11       TB         17         34       NO       NO    -5.0   50.5    False        True       False
# 12571    2019          11      WAS         17         34      NYJ      WAS    -2.0   37.5    False       False        True
# 12572    2019          11      LAC         17         24       KC       KC    -5.5   52.5    False       False       False
# 12573    2019          12      HOU         20         17      IND      HOU    -3.5   46.0     True       False        True
# 12574    2019          12      ATL         22         35       TB      ATL    -3.5   51.5    False        True       False
# 12575    2019          12      BUF         20          3      DEN      BUF    -3.5   37.0     True        True       False
# 12576    2019          12      CHI         19         14      NYG      CHI    -6.0   41.0     True       False       False
# 12577    2019          12      CIN         10         16      PIT      PIT    -6.5   37.0    False       False       False
# 12578    2019          12      CLE         41         24      MIA      CLE   -11.0   46.0     True        True       False
# 12579    2019          12       NE         13          9      DAL       NE    -5.5   44.5     True        True        True
# 12580    2019          12       NO         34         31      CAR       NO   -10.0   46.5     True        True       False
# 12581    2019          12      NYJ         34          3      OAK      OAK    -3.0   44.5     True        True        True
# 12582    2019          12      PHI          9         17      SEA      SEA    -2.0   45.5    False       False        True
# 12583    2019          12       SF         37          8       GB       SF    -3.0   48.0     True        True        True
# 12584    2019          12      TEN         42         20      JAX      TEN    -4.0   42.5     True        True       False
# 12585    2019          12      WAS         19         16      DET      DET    -4.0   40.0     True       False       False
# 12586    2019          12      LAR          6         45      BAL      BAL    -3.5   47.0    False        True        True
# 12587    2019          13      ATL         18         26       NO       NO    -7.0   48.0    False       False        True
# 12588    2019          13      DAL         15         26      BUF      DAL    -6.5   46.5    False       False        True
# 12589    2019          13      DET         20         24      CHI      CHI    -5.5   37.0    False       False        True
# 12590    2019          13      ARI          7         34      LAR      LAR    -2.5   47.0    False       False       False
# 12591    2019          13      BAL         20         17       SF      BAL    -5.5   45.0     True        True        True
# 12592    2019          13      CAR         21         29      WAS      CAR   -10.5   38.5    False       False        True
# 12593    2019          13      CIN         22          6      NYJ      NYJ    -3.0   43.0     True       False        True
# 12594    2019          13      DEN         23         20      LAC      LAC    -4.5   38.5     True       False       False
# 12595    2019          13      HOU         28         22       NE       NE    -3.0   47.0     True        True        True
# 12596    2019          13      IND         17         31      TEN      TEN    -1.0   41.5    False       False        True
# 12597    2019          13      JAX         11         28       TB       TB    -3.0   46.5    False       False        True
# 12598    2019          13       KC         40          9      OAK       KC   -10.5   49.5     True        True       False
# 12599    2019          13      MIA         37         31      PHI      PHI   -10.0   44.5     True       False       False
# 12600    2019          13      NYG         13         31       GB       GB    -6.5   43.5    False       False       False
# 12601    2019          13      PIT         20         13      CLE      CLE    -1.0   40.0     True        True        True
# 12602    2019          13      SEA         37         30      MIN      SEA    -2.5   48.5     True        True        True
# 12603    2019          14      CHI         31         24      DAL      DAL    -3.0   43.0     True        True       False
# 12604    2019          14      ARI         17         23      PIT      PIT    -2.5   43.5    False       False        True
# 12605    2019          14      ATL         40         20      CAR      ATL    -3.5   48.0     True       False       False
# 12606    2019          14      BUF         17         24      BAL      BAL    -6.0   44.0    False        True        True
# 12607    2019          14      CLE         27         19      CIN      CLE    -6.5   43.5     True       False        True
# 12608    2019          14       GB         20         15      WAS       GB   -13.0   42.0     True        True        True
# 12609    2019          14      HOU         24         38      DEN      HOU    -8.0   42.5    False        True        True
# 12610    2019          14      JAX         10         45      LAC      LAC    -3.0   42.0    False       False       False
# 12611    2019          14      LAR         28         12      SEA      LAR    -1.0   47.5     True        True        True
# 12612    2019          14      MIN         20          7      DET      MIN   -11.5   44.0     True       False       False
# 12613    2019          14       NE         16         23       KC       NE    -3.0   48.5    False       False        True
# 12614    2019          14       NO         46         48       SF       NO    -1.5   45.0    False        True       False
# 12615    2019          14      NYJ         22         21      MIA      NYJ    -5.0   47.0     True       False        True
# 12616    2019          14      OAK         21         42      TEN      TEN    -2.5   47.0    False       False        True
# 12617    2019          14       TB         38         35      IND       TB    -3.0   46.5     True        True       False
# 12618    2019          14      PHI         23         17      NYG      PHI    -9.5   45.0     True       False       False
# 12619    2019          15      BAL         42         21      NYJ      BAL   -17.0   44.0     True        True        True
# 12620    2019          15      ARI         38         24      CLE      CLE    -3.0   49.0     True       False        True
# 12621    2019          15      CAR         24         30      SEA      SEA    -6.0   48.5    False       False       False
# 12622    2019          15      CIN         13         34       NE       NE   -10.5   41.5    False       False       False
# 12623    2019          15      DAL         44         21      LAR      LAR    -1.0   48.5     True       False        True
# 12624    2019          15      DET         17         38       TB       TB    -6.0   46.0    False       False        True
# 12625    2019          15       GB         21         13      CHI       GB    -4.5   41.0     True        True        True
# 12626    2019          15       KC         23          3      DEN       KC    -9.0   43.0     True        True        True
# 12627    2019          15      LAC         10         39      MIN      MIN    -1.0   45.0    False        True        True
# 12628    2019          15      NYG         36         20      MIA      NYG    -3.5   46.5     True       False       False
# 12629    2019          15      OAK         16         20      JAX      OAK    -6.5   46.0    False       False       False
# 12630    2019          15      PIT         10         17      BUF      PIT    -1.0   37.0    False        True       False
# 12631    2019          15       SF         22         29      ATL       SF   -10.0   49.5    False        True        True
# 12632    2019          15      TEN         21         24      HOU      TEN    -3.0   50.0    False        True       False
# 12633    2019          15      WAS         27         37      PHI      PHI    -6.5   38.5    False       False        True
# 12634    2019          15       NO         34          7      IND       NO    -8.5   49.0     True       False       False
# 12635    2019          16       NE         24         17      BUF       NE    -6.5   38.5     True        True        True
# 12636    2019          16       SF         34         31      LAR       SF    -7.0   45.5     True       False       False
# 12637    2019          16       TB         20         23      HOU      HOU    -3.0   50.5    False        True        True
# 12638    2019          16      ATL         24         12      JAX      ATL    -7.0   48.0     True        True        True
# 12639    2019          16      CHI          3         26       KC       KC    -7.0   45.5    False       False        True
# 12640    2019          16      CLE         15         31      BAL      BAL   -10.0   49.0    False       False        True
# 12641    2019          16      DEN         27         17      DET      DEN    -7.5   40.0     True       False       False
# 12642    2019          16      IND         38          6      CAR      IND    -7.0   46.5     True       False       False
# 12643    2019          16      LAC         17         24      OAK      LAC    -7.5   45.0    False       False       False
# 12644    2019          16      MIA         38         35      CIN      CIN    -1.5   45.0     True       False       False
# 12645    2019          16      NYJ         16         10      PIT      PIT    -3.0   36.5     True       False       False
# 12646    2019          16      PHI         17          9      DAL      DAL    -2.0   46.5     True        True        True
# 12647    2019          16      SEA         13         27      ARI      SEA    -8.0   51.0    False        True        True
# 12648    2019          16      TEN         28         38       NO       NO    -3.0   49.0    False       False        True
# 12649    2019          16      WAS         35         41      NYG      NYG    -1.0   42.0    False       False        True
# 12650    2019          16      MIN         10         23       GB      MIN    -4.0   46.5    False        True        True
# 12651    2019          17      BAL         28         10      PIT      PIT    -1.0   35.0     True        True       False
# 12652    2019          17      BUF          6         13      NYJ      NYJ    -1.0   37.0    False       False        True
# 12653    2019          17      CAR         10         42       NO       NO   -14.0   44.5    False       False        True
# 12654    2019          17      CIN         33         23      CLE      CLE    -2.5   43.5     True       False       False
# 12655    2019          17      DAL         47         16      WAS      DAL   -12.5   47.5     True       False       False
# 12656    2019          17      DEN         16         15      OAK      DEN    -4.5   41.0     True        True        True
# 12657    2019          17      DET         20         23       GB       GB   -13.0   44.0    False       False        True
# 12658    2019          17      HOU         14         35      TEN      TEN   -10.0   43.0    False        True       False
# 12659    2019          17      JAX         38         20      IND      IND    -5.5   41.5     True       False        True
# 12660    2019          17       KC         31         21      LAC       KC    -9.5   46.0     True        True       False
# 12661    2019          17      LAR         31         24      ARI      LAR    -7.0   45.5     True       False        True
# 12662    2019          17      MIN         19         21      CHI      CHI    -4.5   36.0    False       False       False
# 12663    2019          17       NE         24         27      MIA       NE   -17.0   45.5    False        True        True
# 12664    2019          17      NYG         17         34      PHI      PHI    -3.5   44.5    False        True        True
# 12665    2019          17      SEA         21         26       SF       SF    -3.5   47.0    False       False        True
# 12666    2019          17       TB         22         28      ATL       TB    -1.0   48.5    False       False        True
# 12667    2019    Wildcard      HOU         22         19      BUF      HOU    -2.5   43.0     True       False       False
# 12668    2019    Wildcard       NE         13         20      TEN       NE    -4.5   45.0    False       False        True
# 12669    2019    Wildcard       NO         20         26      MIN       NO    -7.5   49.5    False        True       False
# 12670    2019    Wildcard      PHI          9         17      SEA      PHI    -1.0   44.5    False        True       False
# 12671    2019    Division      BAL         12         28      TEN      BAL   -10.0   47.5    False        True        True
# 12672    2019    Division       SF         27         10      MIN       SF    -7.0   44.5     True        True        True
# 12673    2019    Division       GB         28         23      SEA       GB    -4.5   45.5     True        True        True
# 12674    2019    Division       KC         51         31      HOU       KC   -10.0   50.5     True        True        True
# 12675    2019  Conference       KC         35         24      TEN       KC    -7.0   51.0     True        True        True
# 12676    2019  Conference       SF         37         20       GB       SF    -8.0   46.5     True        True        True
# 12677    2019   Superbowl       KC         31         20       SF       KC    -1.5   53.0     True        True        True

# %%
#Checking the new score after adding the above columns
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state = 14)
scorer = make_scorer (f1_score, pos_label = None, average = 'weighted')

from sklearn.model_selection import cross_val_score  #This just uses a decision tree classifier to look at if the team won their last game or not
X_previouswins = results[['homeLastWin', 'awayLastWin']].values 
clf = DecisionTreeClassifier(random_state = 14)
scores = cross_val_score(clf, X_previouswins, y_true, scoring = scorer)
print('Using just the last result from home and away teams - F1: {0:.4f}'.format(np.mean(scores))) #Using the new information, the F score does go up
# Out:
# Using just the last result from home and away teams - F1: 0.5754

# %%
#What about win streaks
results['homeWinStreak'] = 0
results['awayWinStreak'] = 0
win_streak = defaultdict(int)

for index, row in results.iterrows(): 
    home_team = row['homeTeam'] 
    away_team = row['awayTeam'] 
    row['homeWinStreak'] = win_streak[home_team] 
    row['awayWinStreak'] = win_streak[away_team]
    results.loc[index] = row 
    if row['homeWin']:
        win_streak[home_team] += 1
        win_streak[away_team] = 0
    else:
        win_streak[home_team] = 0
        win_streak[away_team] += 1
        
print(results[['homeTeam', 'homeScore', 'awayScore', 'awayTeam', 'favorite', 'spread', 'total', 'homeWin', 'homeWinStreak', 'awayWinStreak']])
# Out:
#       homeTeam  homeScore  awayScore awayTeam favorite  spread  total  homeWin  homeWinStreak  awayWinStreak
# 12411      CHI          3         10       GB      CHI    -3.0   46.5    False              0              0
# 12412      ARI         27         27      DET      DET    -3.0   45.5    False              0              0
# 12413      CAR         27         30      LAR      LAR    -2.0   49.5    False              0              0
# 12414      CLE         13         43      TEN      CLE    -5.5   44.0    False              0              0
# 12415      DAL         35         17      NYG      DAL    -7.0   44.0     True              0              0
# 12416      JAX         26         40       KC       KC    -3.5   49.0    False              0              0
# 12417      LAC         30         24      IND      LAC    -6.0   44.5     True              0              0
# 12418      MIA         10         59      BAL      BAL    -7.0   40.5    False              0              0
# 12419      MIN         28         12      ATL      MIN    -3.5   47.0     True              0              0
# 12420       NE         33          3      PIT       NE    -5.5   49.0     True              0              0
# 12421      NYJ         16         17      BUF      NYJ    -2.5   41.0    False              0              0
# 12422      PHI         32         27      WAS      PHI   -10.0   44.5     True              0              0
# 12423      SEA         21         20      CIN      SEA    -9.0   44.0     True              0              0
# 12424       TB         17         31       SF       TB    -1.0   51.0    False              0              0
# 12425       NO         30         28      HOU       NO    -6.5   51.5     True              0              0
# 12426      OAK         24         16      DEN      DEN    -3.0   42.5     True              0              0
# 12427      CAR         14         20       TB      CAR    -6.5   48.0    False              0              0
# 12428      ATL         24         20      PHI      PHI    -1.0   53.0     True              0              1
# 12429      BAL         23         17      ARI      BAL   -13.0   45.5     True              1              0
# 12430      CIN         17         41       SF      CIN    -1.0   46.0    False              0              1
# 12431      DEN         14         16      CHI      CHI    -3.0   40.5    False              0              0
# 12432      DET         13         10      LAC      LAC    -1.0   46.5     True              1              1
# 12433       GB         21         16      MIN       GB    -3.0   43.0     True              1              1
# 12434      HOU         13         12      JAX      HOU    -7.0   43.0     True              0              0
# 12435      LAR         27          9       NO      LAR    -2.0   52.0     True              1              1
# 12436      MIA          0         43       NE       NE   -18.0   48.5    False              0              1
# 12437      NYG         14         28      BUF      BUF    -1.0   44.5    False              0              1
# 12438      OAK         10         28       KC       KC    -7.0   53.0    False              1              1
# 12439      PIT         26         28      SEA      PIT    -4.0   47.0    False              0              1
# 12440      TEN         17         19      IND      TEN    -3.5   43.5    False              1              0
# 12441      WAS         21         31      DAL      DAL    -6.0   46.0    False              0              1
# 12442      NYJ          3         23      CLE      CLE    -6.5   45.0    False              0              0
# 12443      JAX         20          7      TEN      TEN    -2.0   38.0     True              0              0
# 12444      ARI         20         38      CAR      ARI    -2.5   45.5    False              0              0
# 12445      BUF         21         17      CIN      BUF    -6.0   43.5     True              2              0
# 12446      CLE         13         20      LAR      LAR    -4.0   48.0    False              1              2
# 12447      DAL         31          6      MIA      DAL   -21.5   46.5     True              2              0
# 12448       GB         27         16      DEN       GB    -7.0   41.5     True              2              0
# 12449      IND         27         24      ATL      IND    -1.5   48.0     True              1              1
# 12450       KC         33         28      BAL       KC    -5.0   52.0     True              2              2
# 12451      LAC         20         27      HOU      LAC    -3.0   49.0    False              0              1
# 12452      MIN         34         14      OAK      MIN    -9.0   43.5     True              0              0
# 12453       NE         30         14      NYJ       NE   -21.0   43.0     True              2              0
# 12454      PHI         24         27      DET      PHI    -4.0   45.0    False              0              2
# 12455       SF         24         20      PIT       SF    -6.0   44.5     True              2              0
# 12456      SEA         27         33       NO      SEA    -5.0   44.0    False              2              0
# 12457       TB         31         32      NYG       TB    -5.0   48.0    False              1              0
# 12458      WAS         15         31      CHI      CHI    -5.0   41.0    False              0              1
# 12459       GB         27         34      PHI       GB    -3.5   46.5    False              3              0
# 12460      ARI         10         27      SEA      SEA    -5.5   48.5    False              0              0
# 12461      ATL         10         24      TEN      ATL    -3.5   46.5    False              0              0
# 12462      BAL         25         40      CLE      BAL    -7.0   47.5    False              0              0
# 12463      BUF         10         16       NE       NE    -7.0   41.5    False              3              3
# 12464      CHI         16          6      MIN      CHI    -1.0   38.5     True              2              1
# 12465      DEN         24         26      JAX      DEN    -2.5   37.5    False              0              1
# 12466      DET         30         34       KC       KC    -7.0   54.5    False              3              3
# 12467      HOU         10         16      CAR      HOU    -5.0   47.5    False              2              1
# 12468      IND         24         31      OAK      IND    -6.0   46.5    False              2              0
# 12469      LAR         40         55       TB      LAR    -9.0   48.5    False              3              0
# 12470      MIA         10         30      LAC      LAC   -15.0   43.5    False              0              0
# 12471       NO         12         10      DAL      DAL    -2.5   47.0     True              1              3
# 12472      NYG         24          3      WAS      NYG    -3.0   48.0     True              1              0
# 12473      PIT         27          3      CIN      PIT    -3.5   45.0     True              0              0
# 12474      SEA         30         29      LAR      SEA    -1.5   48.5     True              1              0
# 12475      CAR         34         27      JAX      CAR    -3.0   40.5     True              2              2
# 12476      CIN         23         26      ARI      CIN    -3.0   46.5    False              0              0
# 12477      DAL         24         34       GB      DAL    -3.0   46.5    False              0              0
# 12478      HOU         53         32      ATL      HOU    -4.0   49.0     True              0              0
# 12479       KC         13         19      IND       KC   -10.5   55.5    False              4              0
# 12480      LAC         13         20      DEN      LAC    -4.5   45.5    False              1              0
# 12481       NO         31         24       TB       NO    -3.0   46.5     True              2              1
# 12482      NYG         10         28      MIN      MIN    -5.5   43.5    False              2              0
# 12483      OAK         24         21      CHI      CHI    -6.5   39.5     True              1              3
# 12484      PHI         31          6      NYJ      PHI   -14.0   43.0     True              1              0
# 12485      PIT         23         26      BAL      BAL    -3.0   44.0    False              1              0
# 12486      TEN          7         14      BUF      TEN    -3.0   39.5    False              1              0
# 12487      WAS          7         33       NE       NE   -16.5   41.5    False              0              4
# 12488       SF         31          3      CLE       SF    -4.5   48.0     True              3              1
# 12489       NE         35         14      NYG       NE   -16.5   43.0     True              5              0
# 12490      ARI         34         33      ATL      ATL    -3.0   52.0     True              1              0
# 12491      BAL         23         17      CIN      BAL   -10.5   46.5     True              1              0
# 12492      CLE         28         32      SEA      CLE    -1.0   45.5    False              0              2
# 12493      DEN         16          0      TEN      DEN    -1.5   41.0     True              1              0
# 12494      JAX          6         13       NO      JAX    -2.5   42.5    False              0              3
# 12495       KC         24         31      HOU       KC    -3.5   54.5    False              0              1
# 12496      LAC         17         24      PIT      LAC    -6.0   42.5    False              0              0
# 12497      LAR          7         20       SF      LAR    -3.0   50.0    False              0              4
# 12498      MIA         16         17      WAS      WAS    -5.5   42.5    False              0              0
# 12499      MIN         38         20      PHI      MIN    -3.5   44.5     True              1              2
# 12500      NYJ         24         22      DAL      DAL    -7.0   43.5     True              0              0
# 12501       TB         26         37      CAR      CAR    -2.0   47.5    False              0              3
# 12502       GB         23         22      DET       GB    -3.5   47.0     True              1              0
# 12503      DEN          6         30       KC       KC    -3.0   49.5    False              2              0
# 12504      ATL         10         37      LAR      LAR    -3.0   54.5    False              0              0
# 12505      BUF         31         21      MIA      BUF   -17.0   42.5     True              1              0
# 12506      CHI         25         36       NO      CHI    -4.0   37.0    False              0              4
# 12507      CIN         17         27      JAX      JAX    -4.0   44.0    False              0              0
# 12508      DAL         37         10      PHI      DAL    -3.0   50.0     True              0              0
# 12509      DET         30         42      MIN      MIN    -2.5   43.5    False              0              2
# 12510       GB         42         24      OAK       GB    -5.5   47.5     True              2              2
# 12511      IND         30         23      HOU      IND    -1.0   46.5     True              1              2
# 12512      NYG         21         27      ARI      NYG    -3.5   50.0    False              0              2
# 12513      SEA         16         30      BAL      SEA    -3.0   48.5    False              3              2
# 12514      TEN         23         20      LAC      TEN    -2.5   42.5     True              0              0
# 12515      WAS          0          9       SF       SF   -10.0   39.0    False              1              5
# 12516      NYJ          0         33       NE       NE   -10.0   43.0    False              1              6
# 12517      MIN         19          9      WAS      MIN   -16.5   42.0     True              3              0
# 12518      ATL         20         27      SEA      SEA    -7.5   48.5    False              0              0
# 12519      BUF         13         31      PHI      BUF    -1.0   39.5    False              2              0
# 12520      CHI         16         17      LAC      CHI    -3.5   41.0    False              0              0
# 12521      DET         31         26      NYG      DET    -6.5   49.0     True              0              0
# 12522      HOU         27         24      OAK      HOU    -6.0   52.0     True              0              0
# 12523      IND         15         13      DEN      IND    -6.0   42.0     True              2              0
# 12524      JAX         29         15      NYJ      JAX    -6.5   40.0     True              1              0
# 12525       KC         24         31       GB       GB    -5.0   47.5    False              1              3
# 12526      LAR         24         10      CIN      LAR   -12.0   48.5     True              1              0
# 12527       NE         27         13      CLE       NE   -10.0   43.0     True              7              0
# 12528       NO         31          9      ARI       NO   -12.5   48.0     True              5              3
# 12529       SF         51         13      CAR       SF    -4.0   40.5     True              6              4
# 12530      TEN         27         23       TB      TEN    -2.0   45.5     True              1              0
# 12531      PIT         27         14      MIA      PIT   -14.0   44.0     True              1              0
# 12532      ARI         25         28       SF       SF   -10.0   43.0    False              0              7
# 12533      BAL         37         20       NE       NE    -3.0   44.5     True              3              8
# 12534      BUF         24          9      WAS      BUF   -10.5   37.0     True              0              0
# 12535      CAR         30         20      TEN      CAR    -3.5   43.0     True              0              2
# 12536      DEN         24         19      CLE      CLE    -4.0   39.0     True              0              0
# 12537      JAX          3         26      HOU      JAX    -1.0   46.0    False              2              1
# 12538       KC         26         23      MIN      MIN    -5.5   45.5     True              0              4
# 12539      LAC         26         11       GB       GB    -4.0   50.0     True              1              4
# 12540      MIA         26         18      NYJ      NYJ    -3.0   42.5     True              0              0
# 12541      OAK         31         24      DET      OAK    -2.5   51.0     True              0              1
# 12542      PHI         22         14      CHI      PHI    -5.0   41.0     True              1              0
# 12543      PIT         26         24      IND      PIT    -1.0   40.0     True              2              3
# 12544      SEA         40         34       TB      SEA    -4.0   51.0     True              1              0
# 12545      NYG         18         37      DAL      DAL    -6.5   48.5    False              0              1
# 12546      OAK         26         24      LAC      LAC    -1.0   49.0     True              1              2
# 12547      CHI         20         13      DET      CHI    -6.0   38.0     True              0              0
# 12548      CIN         13         49      BAL      BAL   -10.5   44.0    False              0              4
# 12549      CLE         19         16      BUF      CLE    -3.0   42.0     True              0              1
# 12550      DAL         24         28      MIN      DAL    -3.0   48.0    False              2              0
# 12551       GB         24         16      CAR       GB    -5.0   49.0     True              0              1
# 12552      IND         12         16      MIA      IND   -11.0   44.0    False              0              1
# 12553       NO          9         26      ATL       NO   -13.5   51.5    False              6              0
# 12554      NYJ         34         27      NYG      NYG    -3.0   43.0     True              0              0
# 12555      PIT         17         12      LAR      LAR    -4.5   43.5     True              3              2
# 12556       TB         30         27      ARI       TB    -5.5   51.5     True              0              0
# 12557      TEN         35         32       KC       KC    -6.0   49.0     True              0              1
# 12558       SF         24         27      SEA       SF    -6.5   46.5    False              8              2
# 12559      CLE         21          7      PIT      CLE    -3.0   41.5     True              1              4
# 12560      BAL         41          7      HOU      BAL    -4.5   51.0     True              5              2
# 12561      CAR          3         29      ATL      CAR    -4.0   49.0    False              0              1
# 12562      DET         27         35      DAL      DAL    -7.0   46.5    False              0              0
# 12563      IND         33         13      JAX      IND    -2.5   41.5     True              0              0
# 12564      LAR         17          7      CHI      LAR    -5.5   40.0     True              0              1
# 12565      MIA         20         37      BUF      BUF    -7.0   41.0    False              2              0
# 12566      MIN         27         23      DEN      MIN   -10.0   40.0     True              1              1
# 12567      OAK         17         10      CIN      OAK   -13.0   48.0     True              2              0
# 12568      PHI         10         17       NE       NE    -4.5   45.0    False              2              0
# 12569       SF         36         26      ARI       SF   -10.0   44.0     True              0              0
# 12570       TB         17         34       NO       NO    -5.0   50.5    False              1              0
# 12571      WAS         17         34      NYJ      WAS    -2.0   37.5    False              0              1
# 12572      LAC         17         24       KC       KC    -5.5   52.5    False              0              0
# 12573      HOU         20         17      IND      HOU    -3.5   46.0     True              0              1
# 12574      ATL         22         35       TB      ATL    -3.5   51.5    False              2              0
# 12575      BUF         20          3      DEN      BUF    -3.5   37.0     True              1              0
# 12576      CHI         19         14      NYG      CHI    -6.0   41.0     True              0              0
# 12577      CIN         10         16      PIT      PIT    -6.5   37.0    False              0              0
# 12578      CLE         41         24      MIA      CLE   -11.0   46.0     True              2              0
# 12579       NE         13          9      DAL       NE    -5.5   44.5     True              1              1
# 12580       NO         34         31      CAR       NO   -10.0   46.5     True              1              0
# 12581      NYJ         34          3      OAK      OAK    -3.0   44.5     True              2              3
# 12582      PHI          9         17      SEA      SEA    -2.0   45.5    False              0              3
# 12583       SF         37          8       GB       SF    -3.0   48.0     True              1              1
# 12584      TEN         42         20      JAX      TEN    -4.0   42.5     True              1              0
# 12585      WAS         19         16      DET      DET    -4.0   40.0     True              0              0
# 12586      LAR          6         45      BAL      BAL    -3.5   47.0    False              1              6
# 12587      ATL         18         26       NO       NO    -7.0   48.0    False              0              2
# 12588      DAL         15         26      BUF      DAL    -6.5   46.5    False              0              2
# 12589      DET         20         24      CHI      CHI    -5.5   37.0    False              0              1
# 12590      ARI          7         34      LAR      LAR    -2.5   47.0    False              0              0
# 12591      BAL         20         17       SF      BAL    -5.5   45.0     True              7              2
# 12592      CAR         21         29      WAS      CAR   -10.5   38.5    False              0              1
# 12593      CIN         22          6      NYJ      NYJ    -3.0   43.0     True              0              3
# 12594      DEN         23         20      LAC      LAC    -4.5   38.5     True              0              0
# 12595      HOU         28         22       NE       NE    -3.0   47.0     True              1              2
# 12596      IND         17         31      TEN      TEN    -1.0   41.5    False              0              2
# 12597      JAX         11         28       TB       TB    -3.0   46.5    False              0              1
# 12598       KC         40          9      OAK       KC   -10.5   49.5     True              1              0
# 12599      MIA         37         31      PHI      PHI   -10.0   44.5     True              0              0
# 12600      NYG         13         31       GB       GB    -6.5   43.5    False              0              0
# 12601      PIT         20         13      CLE      CLE    -1.0   40.0     True              1              3
# 12602      SEA         37         30      MIN      SEA    -2.5   48.5     True              4              2
# 12603      CHI         31         24      DAL      DAL    -3.0   43.0     True              2              0
# 12604      ARI         17         23      PIT      PIT    -2.5   43.5    False              0              2
# 12605      ATL         40         20      CAR      ATL    -3.5   48.0     True              0              0
# 12606      BUF         17         24      BAL      BAL    -6.0   44.0    False              3              8
# 12607      CLE         27         19      CIN      CLE    -6.5   43.5     True              0              1
# 12608       GB         20         15      WAS       GB   -13.0   42.0     True              1              2
# 12609      HOU         24         38      DEN      HOU    -8.0   42.5    False              2              1
# 12610      JAX         10         45      LAC      LAC    -3.0   42.0    False              0              0
# 12611      LAR         28         12      SEA      LAR    -1.0   47.5     True              1              5
# 12612      MIN         20          7      DET      MIN   -11.5   44.0     True              0              0
# 12613       NE         16         23       KC       NE    -3.0   48.5    False              0              2
# 12614       NO         46         48       SF       NO    -1.5   45.0    False              3              0
# 12615      NYJ         22         21      MIA      NYJ    -5.0   47.0     True              0              1
# 12616      OAK         21         42      TEN      TEN    -2.5   47.0    False              0              3
# 12617       TB         38         35      IND       TB    -3.0   46.5     True              2              0
# 12618      PHI         23         17      NYG      PHI    -9.5   45.0     True              0              0
# 12619      BAL         42         21      NYJ      BAL   -17.0   44.0     True              9              1
# 12620      ARI         38         24      CLE      CLE    -3.0   49.0     True              0              1
# 12621      CAR         24         30      SEA      SEA    -6.0   48.5    False              0              0
# 12622      CIN         13         34       NE       NE   -10.5   41.5    False              0              0
# 12623      DAL         44         21      LAR      LAR    -1.0   48.5     True              0              2
# 12624      DET         17         38       TB       TB    -6.0   46.0    False              0              3
# 12625       GB         21         13      CHI       GB    -4.5   41.0     True              2              3
# 12626       KC         23          3      DEN       KC    -9.0   43.0     True              3              2
# 12627      LAC         10         39      MIN      MIN    -1.0   45.0    False              1              1
# 12628      NYG         36         20      MIA      NYG    -3.5   46.5     True              0              0
# 12629      OAK         16         20      JAX      OAK    -6.5   46.0    False              0              0
# 12630      PIT         10         17      BUF      PIT    -1.0   37.0    False              3              0
# 12631       SF         22         29      ATL       SF   -10.0   49.5    False              1              1
# 12632      TEN         21         24      HOU      TEN    -3.0   50.0    False              4              0
# 12633      WAS         27         37      PHI      PHI    -6.5   38.5    False              0              1
# 12634       NO         34          7      IND       NO    -8.5   49.0     True              0              0
# 12635       NE         24         17      BUF       NE    -6.5   38.5     True              1              1
# 12636       SF         34         31      LAR       SF    -7.0   45.5     True              0              0
# 12637       TB         20         23      HOU      HOU    -3.0   50.5    False              4              1
# 12638      ATL         24         12      JAX      ATL    -7.0   48.0     True              2              1
# 12639      CHI          3         26       KC       KC    -7.0   45.5    False              0              4
# 12640      CLE         15         31      BAL      BAL   -10.0   49.0    False              0             10
# 12641      DEN         27         17      DET      DEN    -7.5   40.0     True              0              0
# 12642      IND         38          6      CAR      IND    -7.0   46.5     True              0              0
# 12643      LAC         17         24      OAK      LAC    -7.5   45.0    False              0              0
# 12644      MIA         38         35      CIN      CIN    -1.5   45.0     True              0              0
# 12645      NYJ         16         10      PIT      PIT    -3.0   36.5     True              0              0
# 12646      PHI         17          9      DAL      DAL    -2.0   46.5     True              2              1
# 12647      SEA         13         27      ARI      SEA    -8.0   51.0    False              1              1
# 12648      TEN         28         38       NO       NO    -3.0   49.0    False              0              1
# 12649      WAS         35         41      NYG      NYG    -1.0   42.0    False              0              1
# 12650      MIN         10         23       GB      MIN    -4.0   46.5    False              2              3
# 12651      BAL         28         10      PIT      PIT    -1.0   35.0     True             11              0
# 12652      BUF          6         13      NYJ      NYJ    -1.0   37.0    False              0              1
# 12653      CAR         10         42       NO       NO   -14.0   44.5    False              0              2
# 12654      CIN         33         23      CLE      CLE    -2.5   43.5     True              0              0
# 12655      DAL         47         16      WAS      DAL   -12.5   47.5     True              0              0
# 12656      DEN         16         15      OAK      DEN    -4.5   41.0     True              1              1
# 12657      DET         20         23       GB       GB   -13.0   44.0    False              0              4
# 12658      HOU         14         35      TEN      TEN   -10.0   43.0    False              2              0
# 12659      JAX         38         20      IND      IND    -5.5   41.5     True              0              1
# 12660       KC         31         21      LAC       KC    -9.5   46.0     True              5              0
# 12661      LAR         31         24      ARI      LAR    -7.0   45.5     True              0              2
# 12662      MIN         19         21      CHI      CHI    -4.5   36.0    False              0              0
# 12663       NE         24         27      MIA       NE   -17.0   45.5    False              2              1
# 12664      NYG         17         34      PHI      PHI    -3.5   44.5    False              2              3
# 12665      SEA         21         26       SF       SF    -3.5   47.0    False              0              1
# 12666       TB         22         28      ATL       TB    -1.0   48.5    False              0              3
# 12667      HOU         22         19      BUF      HOU    -2.5   43.0     True              0              0
# 12668       NE         13         20      TEN       NE    -4.5   45.0    False              0              1
# 12669       NO         20         26      MIN       NO    -7.5   49.5    False              3              0
# 12670      PHI          9         17      SEA      PHI    -1.0   44.5    False              4              0
# 12671      BAL         12         28      TEN      BAL   -10.0   47.5    False             12              2
# 12672       SF         27         10      MIN       SF    -7.0   44.5     True              2              1
# 12673       GB         28         23      SEA       GB    -4.5   45.5     True              5              1
# 12674       KC         51         31      HOU       KC   -10.0   50.5     True              6              1
# 12675       KC         35         24      TEN       KC    -7.0   51.0     True              7              3
# 12676       SF         37         20       GB       SF    -8.0   46.5     True              3              6
# 12677       KC         31         20       SF       KC    -1.5   53.0     True              8              4

# %%
#Checking new score after adding win streaks
X_winstreak = results[['homeLastWin', 'awayLastWin', 'homeWinStreak', 'awayWinStreak']].values
scores = cross_val_score(clf, X_winstreak, y_true, scoring = scorer)
print('Using whether the hometeam is on a winstreak or not - F1: {0:.4f}'.format(np.mean(scores)))
# Out:
# Using whether the hometeam is on a winstreak or not - F1: 0.5464

# %%
#Bringing in 2018 Rankings
rankings = pd.read_csv("Z:\\Coding\\Myproj\\NFL\\Data\\2018_nfl_rankings.csv")
rankings['Tm'] = rankings['Tm'].replace(dict)
rankings['rank'] = rankings['W'].rank(method='first', ascending = False, pct = False)
rankings = rankings.sort_values('rank')
rankings.set_index('Tm', inplace = True)
print(rankings)
# Out:
#       W   L  T   W-L%   PF   PA   PD   MoV  SoS   SRS  OSRS  DSRS  rank
# Tm
# NO   13   3  0  0.813  504  353  151   9.4  0.6  10.1   7.9   2.2   1.0
# LAR  13   3  0  0.813  527  384  143   8.9 -0.4   8.5   9.5  -1.1   2.0
# KC   12   4  0  0.750  565  421  144   9.0 -0.1   8.9  12.6  -3.8   3.0
# LAC  12   4  0  0.750  428  329   99   6.2 -0.2   6.0   3.0   2.9   4.0
# CHI  12   4  0  0.750  421  283  138   8.6 -2.3   6.3   1.5   4.8   5.0
# NE   11   5  0  0.688  436  325  111   6.9 -1.8   5.2   3.1   2.1   6.0
# HOU  11   5  0  0.688  402  316   86   5.4 -1.5   3.8   2.4   1.4   7.0
# BAL  10   6  0  0.625  389  287  102   6.4  0.6   7.0   0.6   6.4   8.0
# IND  10   6  0  0.625  433  344   89   5.6 -2.2   3.4   3.9  -0.6   9.0
# DAL  10   6  0  0.625  339  324   15   0.9  0.2   1.1  -1.9   2.9  10.0
# SEA  10   6  0  0.625  428  347   81   5.1 -0.6   4.5   3.0   1.5  11.0
# PIT   9   6  1  0.594  428  360   68   4.3  1.3   5.6   3.9   1.7  12.0
# TEN   9   7  0  0.563  310  303    7   0.4 -0.2   0.2  -3.2   3.5  13.0
# PHI   9   7  0  0.563  367  348   19   1.2  0.5   1.7   0.0   1.8  14.0
# MIN   8   7  1  0.531  360  341   19   1.2 -0.6   0.6  -1.2   1.8  15.0
# MIA   7   9  0  0.438  319  433 -114  -7.1 -1.7  -8.8  -3.6  -5.2  16.0
# CLE   7   8  1  0.469  359  392  -33  -2.1  1.7  -0.3  -1.0   0.6  17.0
# WAS   7   9  0  0.438  281  359  -78  -4.9 -0.1  -4.9  -5.6   0.6  18.0
# ATL   7   9  0  0.438  414  423   -9  -0.6  0.4  -0.1   2.5  -2.6  19.0
# CAR   7   9  0  0.438  376  382   -6  -0.4  1.3   0.9   0.1   0.8  20.0
# BUF   6  10  0  0.375  269  374 -105  -6.6 -0.3  -6.9  -6.3  -0.6  21.0
# CIN   6  10  0  0.375  368  455  -87  -5.4  2.0  -3.4   0.0  -3.4  22.0
# DEN   6  10  0  0.375  329  349  -20  -1.3  0.7  -0.5  -3.6   3.1  23.0
# GB    6   9  1  0.406  376  400  -24  -1.5 -1.2  -2.7   0.0  -2.7  24.0
# DET   6  10  0  0.375  324  360  -36  -2.3 -0.8  -3.0  -3.3   0.3  25.0
# JAX   5  11  0  0.313  245  316  -71  -4.4  0.4  -4.0  -8.1   4.0  26.0
# NYG   5  11  0  0.313  369  412  -43  -2.7  0.5  -2.2   0.8  -2.9  27.0
# TB    5  11  0  0.313  396  464  -68  -4.3  1.7  -2.6   2.0  -4.6  28.0
# NYJ   4  12  0  0.250  333  441 -108  -6.8 -1.1  -7.8  -2.0  -5.9  29.0
# OAK   4  12  0  0.250  290  467 -177 -11.1  1.8  -9.3  -5.2  -4.1  30.0
# SF    4  12  0  0.250  342  435  -93  -5.8  0.3  -5.5  -2.5  -3.1  31.0
# ARI   3  13  0  0.188  225  425 -200 -12.5  1.0 -11.5  -9.6  -1.9  32.0

# %%
#Creating a new feature -- HomeTeamRanksHigher
def home_team_ranked_higher(row):
    home_team = row['homeTeam']
    away_team = row['awayTeam']
    home_rank = rankings.loc[home_team]['rank']
    away_rank = rankings.loc[away_team]['rank']
    return home_rank < away_rank #ranking higher == lower

results['homeTeamRankedHigher'] = results.apply(home_team_ranked_higher, axis = 1)
print(results.head(40))
# Out:
#             date  season week  playoff homeTeam  homeScore  awayScore awayTeam favorite  spread  total  temp  wind humidity detail  homeWin homeLastWin awayLastWin  homeWinStreak  awayWinStreak  homeTeamRankedHigher
# 12411   9/5/2019    2019    1    False      CHI          3         10       GB      CHI    -3.0   46.5   NaN   NaN      NaN    NaN    False           0           0              0              0                  True
# 12412   9/8/2019    2019    1    False      ARI         27         27      DET      DET    -3.0   45.5  72.0   0.0      NaN   DOME    False           0           0              0              0                 False
# 12413   9/8/2019    2019    1    False      CAR         27         30      LAR      LAR    -2.0   49.5   NaN   NaN      NaN    NaN    False           0           0              0              0                 False
# 12414   9/8/2019    2019    1    False      CLE         13         43      TEN      CLE    -5.5   44.0   NaN   NaN      NaN    NaN    False           0           0              0              0                 False
# 12415   9/8/2019    2019    1    False      DAL         35         17      NYG      DAL    -7.0   44.0  72.0   0.0      NaN   DOME     True           0           0              0              0                  True
# 12416   9/8/2019    2019    1    False      JAX         26         40       KC       KC    -3.5   49.0   NaN   NaN      NaN    NaN    False           0           0              0              0                 False
# 12417   9/8/2019    2019    1    False      LAC         30         24      IND      LAC    -6.0   44.5   NaN   NaN      NaN    NaN     True           0           0              0              0                  True
# 12418   9/8/2019    2019    1    False      MIA         10         59      BAL      BAL    -7.0   40.5   NaN   NaN      NaN    NaN    False           0           0              0              0                 False
# 12419   9/8/2019    2019    1    False      MIN         28         12      ATL      MIN    -3.5   47.0   NaN   NaN      NaN    NaN     True           0           0              0              0                  True
# 12420   9/8/2019    2019    1    False       NE         33          3      PIT       NE    -5.5   49.0   NaN   NaN      NaN    NaN     True           0           0              0              0                  True
# 12421   9/8/2019    2019    1    False      NYJ         16         17      BUF      NYJ    -2.5   41.0   NaN   NaN      NaN    NaN    False           0           0              0              0                 False
# 12422   9/8/2019    2019    1    False      PHI         32         27      WAS      PHI   -10.0   44.5   NaN   NaN      NaN    NaN     True           0           0              0              0                  True
# 12423   9/8/2019    2019    1    False      SEA         21         20      CIN      SEA    -9.0   44.0   NaN   NaN      NaN    NaN     True           0           0              0              0                  True
# 12424   9/8/2019    2019    1    False       TB         17         31       SF       TB    -1.0   51.0   NaN   NaN      NaN    NaN    False           0           0              0              0                  True
# 12425   9/9/2019    2019    1    False       NO         30         28      HOU       NO    -6.5   51.5  72.0   0.0      NaN   DOME     True           0           0              0              0                  True
# 12426   9/9/2019    2019    1    False      OAK         24         16      DEN      DEN    -3.0   42.5   NaN   NaN      NaN    NaN     True           0           0              0              0                 False
# 12427  9/12/2019    2019    2    False      CAR         14         20       TB      CAR    -6.5   48.0   NaN   NaN      NaN    NaN    False       False       False              0              0                  True
# 12428  9/15/2019    2019    2    False      ATL         24         20      PHI      PHI    -1.0   53.0  72.0   0.0      NaN   DOME     True       False        True              0              1                 False
# 12429  9/15/2019    2019    2    False      BAL         23         17      ARI      BAL   -13.0   45.5   NaN   NaN      NaN    NaN     True        True       False              1              0                  True
# 12430  9/15/2019    2019    2    False      CIN         17         41       SF      CIN    -1.0   46.0   NaN   NaN      NaN    NaN    False       False        True              0              1                  True
# 12431  9/15/2019    2019    2    False      DEN         14         16      CHI      CHI    -3.0   40.5   NaN   NaN      NaN    NaN    False       False       False              0              0                 False
# 12432  9/15/2019    2019    2    False      DET         13         10      LAC      LAC    -1.0   46.5  72.0   0.0      NaN   DOME     True        True        True              1              1                 False
# 12433  9/15/2019    2019    2    False       GB         21         16      MIN       GB    -3.0   43.0   NaN   NaN      NaN    NaN     True        True        True              1              1                 False
# 12434  9/15/2019    2019    2    False      HOU         13         12      JAX      HOU    -7.0   43.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True
# 12435  9/15/2019    2019    2    False      LAR         27          9       NO      LAR    -2.0   52.0   NaN   NaN      NaN    NaN     True        True        True              1              1                 False
# 12436  9/15/2019    2019    2    False      MIA          0         43       NE       NE   -18.0   48.5   NaN   NaN      NaN    NaN    False       False        True              0              1                 False
# 12437  9/15/2019    2019    2    False      NYG         14         28      BUF      BUF    -1.0   44.5   NaN   NaN      NaN    NaN    False       False        True              0              1                 False
# 12438  9/15/2019    2019    2    False      OAK         10         28       KC       KC    -7.0   53.0   NaN   NaN      NaN    NaN    False        True        True              1              1                 False
# 12439  9/15/2019    2019    2    False      PIT         26         28      SEA      PIT    -4.0   47.0   NaN   NaN      NaN    NaN    False       False        True              0              1                 False
# 12440  9/15/2019    2019    2    False      TEN         17         19      IND      TEN    -3.5   43.5   NaN   NaN      NaN    NaN    False        True       False              1              0                 False
# 12441  9/15/2019    2019    2    False      WAS         21         31      DAL      DAL    -6.0   46.0   NaN   NaN      NaN    NaN    False       False        True              0              1                 False
# 12442  9/16/2019    2019    2    False      NYJ          3         23      CLE      CLE    -6.5   45.0   NaN   NaN      NaN    NaN    False       False       False              0              0                 False
# 12443  9/19/2019    2019    3    False      JAX         20          7      TEN      TEN    -2.0   38.0   NaN   NaN      NaN    NaN     True       False       False              0              0                 False
# 12444  9/22/2019    2019    3    False      ARI         20         38      CAR      ARI    -2.5   45.5  72.0   0.0      NaN   DOME    False       False       False              0              0                 False
# 12445  9/22/2019    2019    3    False      BUF         21         17      CIN      BUF    -6.0   43.5   NaN   NaN      NaN    NaN     True        True       False              2              0                  True
# 12446  9/22/2019    2019    3    False      CLE         13         20      LAR      LAR    -4.0   48.0   NaN   NaN      NaN    NaN    False        True        True              1              2                 False
# 12447  9/22/2019    2019    3    False      DAL         31          6      MIA      DAL   -21.5   46.5  72.0   0.0      NaN   DOME     True        True       False              2              0                  True
# 12448  9/22/2019    2019    3    False       GB         27         16      DEN       GB    -7.0   41.5   NaN   NaN      NaN    NaN     True        True       False              2              0                 False
# 12449  9/22/2019    2019    3    False      IND         27         24      ATL      IND    -1.5   48.0  72.0   0.0      NaN   DOME     True        True        True              1              1                  True
# 12450  9/22/2019    2019    3    False       KC         33         28      BAL       KC    -5.0   52.0   NaN   NaN      NaN    NaN     True        True        True              2              2                  True

# %%
X_homehigher = results[['homeLastWin', 'awayLastWin', 'homeTeamRankedHigher']].values
scores = cross_val_score(clf, X_homehigher, y_true, scoring = scorer)
print('Using whether the home team is ranked higher last season - F1: {0:.4f}'.format(np.mean(scores)))
# Out:
# Using whether the home team is ranked higher last season - F1: 0.6707

# %%
#Next feature looks at which team won in the last encounter between the two teams

last_match_winner = defaultdict(int)

def home_team_won_last (row):
    home_team = row['homeTeam']
    away_team = row['awayTeam']
    #sort for consistent ordering
    teams = tuple(sorted([home_team, away_team]))
    result = 1 if last_match_winner[teams] == row['homeTeam'] else 0
    #update record for next encounter
    winner = row['homeTeam'] if row['homeWin'] else row['awayTeam']
    last_match_winner[teams] = winner
    return result 

results['homeTeamWonLast'] = results.apply(home_team_won_last, axis=1)
print(results)
# Out:
#              date  season        week  playoff homeTeam  homeScore  awayScore awayTeam favorite  spread  total  temp  wind humidity detail  homeWin homeLastWin awayLastWin  homeWinStreak  awayWinStreak  homeTeamRankedHigher  homeTeamWonLast
# 12411    9/5/2019    2019           1    False      CHI          3         10       GB      CHI    -3.0   46.5   NaN   NaN      NaN    NaN    False           0           0              0              0                  True                0
# 12412    9/8/2019    2019           1    False      ARI         27         27      DET      DET    -3.0   45.5  72.0   0.0      NaN   DOME    False           0           0              0              0                 False                0
# 12413    9/8/2019    2019           1    False      CAR         27         30      LAR      LAR    -2.0   49.5   NaN   NaN      NaN    NaN    False           0           0              0              0                 False                0
# 12414    9/8/2019    2019           1    False      CLE         13         43      TEN      CLE    -5.5   44.0   NaN   NaN      NaN    NaN    False           0           0              0              0                 False                0
# 12415    9/8/2019    2019           1    False      DAL         35         17      NYG      DAL    -7.0   44.0  72.0   0.0      NaN   DOME     True           0           0              0              0                  True                0
# 12416    9/8/2019    2019           1    False      JAX         26         40       KC       KC    -3.5   49.0   NaN   NaN      NaN    NaN    False           0           0              0              0                 False                0
# 12417    9/8/2019    2019           1    False      LAC         30         24      IND      LAC    -6.0   44.5   NaN   NaN      NaN    NaN     True           0           0              0              0                  True                0
# 12418    9/8/2019    2019           1    False      MIA         10         59      BAL      BAL    -7.0   40.5   NaN   NaN      NaN    NaN    False           0           0              0              0                 False                0
# 12419    9/8/2019    2019           1    False      MIN         28         12      ATL      MIN    -3.5   47.0   NaN   NaN      NaN    NaN     True           0           0              0              0                  True                0
# 12420    9/8/2019    2019           1    False       NE         33          3      PIT       NE    -5.5   49.0   NaN   NaN      NaN    NaN     True           0           0              0              0                  True                0
# 12421    9/8/2019    2019           1    False      NYJ         16         17      BUF      NYJ    -2.5   41.0   NaN   NaN      NaN    NaN    False           0           0              0              0                 False                0
# 12422    9/8/2019    2019           1    False      PHI         32         27      WAS      PHI   -10.0   44.5   NaN   NaN      NaN    NaN     True           0           0              0              0                  True                0
# 12423    9/8/2019    2019           1    False      SEA         21         20      CIN      SEA    -9.0   44.0   NaN   NaN      NaN    NaN     True           0           0              0              0                  True                0
# 12424    9/8/2019    2019           1    False       TB         17         31       SF       TB    -1.0   51.0   NaN   NaN      NaN    NaN    False           0           0              0              0                  True                0
# 12425    9/9/2019    2019           1    False       NO         30         28      HOU       NO    -6.5   51.5  72.0   0.0      NaN   DOME     True           0           0              0              0                  True                0
# 12426    9/9/2019    2019           1    False      OAK         24         16      DEN      DEN    -3.0   42.5   NaN   NaN      NaN    NaN     True           0           0              0              0                 False                0
# 12427   9/12/2019    2019           2    False      CAR         14         20       TB      CAR    -6.5   48.0   NaN   NaN      NaN    NaN    False       False       False              0              0                  True                0
# 12428   9/15/2019    2019           2    False      ATL         24         20      PHI      PHI    -1.0   53.0  72.0   0.0      NaN   DOME     True       False        True              0              1                 False                0
# 12429   9/15/2019    2019           2    False      BAL         23         17      ARI      BAL   -13.0   45.5   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12430   9/15/2019    2019           2    False      CIN         17         41       SF      CIN    -1.0   46.0   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12431   9/15/2019    2019           2    False      DEN         14         16      CHI      CHI    -3.0   40.5   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12432   9/15/2019    2019           2    False      DET         13         10      LAC      LAC    -1.0   46.5  72.0   0.0      NaN   DOME     True        True        True              1              1                 False                0
# 12433   9/15/2019    2019           2    False       GB         21         16      MIN       GB    -3.0   43.0   NaN   NaN      NaN    NaN     True        True        True              1              1                 False                0
# 12434   9/15/2019    2019           2    False      HOU         13         12      JAX      HOU    -7.0   43.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12435   9/15/2019    2019           2    False      LAR         27          9       NO      LAR    -2.0   52.0   NaN   NaN      NaN    NaN     True        True        True              1              1                 False                0
# 12436   9/15/2019    2019           2    False      MIA          0         43       NE       NE   -18.0   48.5   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12437   9/15/2019    2019           2    False      NYG         14         28      BUF      BUF    -1.0   44.5   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12438   9/15/2019    2019           2    False      OAK         10         28       KC       KC    -7.0   53.0   NaN   NaN      NaN    NaN    False        True        True              1              1                 False                0
# 12439   9/15/2019    2019           2    False      PIT         26         28      SEA      PIT    -4.0   47.0   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12440   9/15/2019    2019           2    False      TEN         17         19      IND      TEN    -3.5   43.5   NaN   NaN      NaN    NaN    False        True       False              1              0                 False                0
# 12441   9/15/2019    2019           2    False      WAS         21         31      DAL      DAL    -6.0   46.0   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12442   9/16/2019    2019           2    False      NYJ          3         23      CLE      CLE    -6.5   45.0   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12443   9/19/2019    2019           3    False      JAX         20          7      TEN      TEN    -2.0   38.0   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12444   9/22/2019    2019           3    False      ARI         20         38      CAR      ARI    -2.5   45.5  72.0   0.0      NaN   DOME    False       False       False              0              0                 False                0
# 12445   9/22/2019    2019           3    False      BUF         21         17      CIN      BUF    -6.0   43.5   NaN   NaN      NaN    NaN     True        True       False              2              0                  True                0
# 12446   9/22/2019    2019           3    False      CLE         13         20      LAR      LAR    -4.0   48.0   NaN   NaN      NaN    NaN    False        True        True              1              2                 False                0
# 12447   9/22/2019    2019           3    False      DAL         31          6      MIA      DAL   -21.5   46.5  72.0   0.0      NaN   DOME     True        True       False              2              0                  True                0
# 12448   9/22/2019    2019           3    False       GB         27         16      DEN       GB    -7.0   41.5   NaN   NaN      NaN    NaN     True        True       False              2              0                 False                0
# 12449   9/22/2019    2019           3    False      IND         27         24      ATL      IND    -1.5   48.0  72.0   0.0      NaN   DOME     True        True        True              1              1                  True                0
# 12450   9/22/2019    2019           3    False       KC         33         28      BAL       KC    -5.0   52.0   NaN   NaN      NaN    NaN     True        True        True              2              2                  True                0
# 12451   9/22/2019    2019           3    False      LAC         20         27      HOU      LAC    -3.0   49.0   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12452   9/22/2019    2019           3    False      MIN         34         14      OAK      MIN    -9.0   43.5   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12453   9/22/2019    2019           3    False       NE         30         14      NYJ       NE   -21.0   43.0   NaN   NaN      NaN    NaN     True        True       False              2              0                  True                0
# 12454   9/22/2019    2019           3    False      PHI         24         27      DET      PHI    -4.0   45.0   NaN   NaN      NaN    NaN    False       False        True              0              2                  True                0
# 12455   9/22/2019    2019           3    False       SF         24         20      PIT       SF    -6.0   44.5   NaN   NaN      NaN    NaN     True        True       False              2              0                 False                0
# 12456   9/22/2019    2019           3    False      SEA         27         33       NO      SEA    -5.0   44.0   NaN   NaN      NaN    NaN    False        True       False              2              0                 False                0
# 12457   9/22/2019    2019           3    False       TB         31         32      NYG       TB    -5.0   48.0   NaN   NaN      NaN    NaN    False        True       False              1              0                 False                0
# 12458   9/23/2019    2019           3    False      WAS         15         31      CHI      CHI    -5.0   41.0   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12459   9/26/2019    2019           4    False       GB         27         34      PHI       GB    -3.5   46.5   NaN   NaN      NaN    NaN    False        True       False              3              0                 False                0
# 12460   9/29/2019    2019           4    False      ARI         10         27      SEA      SEA    -5.5   48.5  72.0   0.0      NaN   DOME    False       False       False              0              0                 False                0
# 12461   9/29/2019    2019           4    False      ATL         10         24      TEN      ATL    -3.5   46.5  72.0   0.0      NaN   DOME    False       False       False              0              0                 False                0
# 12462   9/29/2019    2019           4    False      BAL         25         40      CLE      BAL    -7.0   47.5   NaN   NaN      NaN    NaN    False       False       False              0              0                  True                0
# 12463   9/29/2019    2019           4    False      BUF         10         16       NE       NE    -7.0   41.5   NaN   NaN      NaN    NaN    False        True        True              3              3                 False                0
# 12464   9/29/2019    2019           4    False      CHI         16          6      MIN      CHI    -1.0   38.5   NaN   NaN      NaN    NaN     True        True        True              2              1                  True                0
# 12465   9/29/2019    2019           4    False      DEN         24         26      JAX      DEN    -2.5   37.5   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12466   9/29/2019    2019           4    False      DET         30         34       KC       KC    -7.0   54.5  72.0   0.0      NaN   DOME    False        True        True              3              3                 False                0
# 12467   9/29/2019    2019           4    False      HOU         10         16      CAR      HOU    -5.0   47.5  72.0   0.0      NaN   DOME    False        True        True              2              1                  True                0
# 12468   9/29/2019    2019           4    False      IND         24         31      OAK      IND    -6.0   46.5  72.0   0.0      NaN   DOME    False        True       False              2              0                  True                0
# 12469   9/29/2019    2019           4    False      LAR         40         55       TB      LAR    -9.0   48.5   NaN   NaN      NaN    NaN    False        True       False              3              0                  True                0
# 12470   9/29/2019    2019           4    False      MIA         10         30      LAC      LAC   -15.0   43.5   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12471   9/29/2019    2019           4    False       NO         12         10      DAL      DAL    -2.5   47.0  72.0   0.0      NaN   DOME     True        True        True              1              3                  True                0
# 12472   9/29/2019    2019           4    False      NYG         24          3      WAS      NYG    -3.0   48.0   NaN   NaN      NaN    NaN     True        True       False              1              0                 False                0
# 12473   9/30/2019    2019           4    False      PIT         27          3      CIN      PIT    -3.5   45.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12474   10/3/2019    2019           5    False      SEA         30         29      LAR      SEA    -1.5   48.5   NaN   NaN      NaN    NaN     True        True       False              1              0                 False                0
# 12475   10/6/2019    2019           5    False      CAR         34         27      JAX      CAR    -3.0   40.5   NaN   NaN      NaN    NaN     True        True        True              2              2                  True                0
# 12476   10/6/2019    2019           5    False      CIN         23         26      ARI      CIN    -3.0   46.5   NaN   NaN      NaN    NaN    False       False       False              0              0                  True                0
# 12477   10/6/2019    2019           5    False      DAL         24         34       GB      DAL    -3.0   46.5  72.0   0.0      NaN   DOME    False       False       False              0              0                  True                0
# 12478   10/6/2019    2019           5    False      HOU         53         32      ATL      HOU    -4.0   49.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12479   10/6/2019    2019           5    False       KC         13         19      IND       KC   -10.5   55.5   NaN   NaN      NaN    NaN    False        True       False              4              0                  True                0
# 12480   10/6/2019    2019           5    False      LAC         13         20      DEN      LAC    -4.5   45.5   NaN   NaN      NaN    NaN    False        True       False              1              0                  True                0
# 12481   10/6/2019    2019           5    False       NO         31         24       TB       NO    -3.0   46.5  72.0   0.0      NaN   DOME     True        True        True              2              1                  True                0
# 12482   10/6/2019    2019           5    False      NYG         10         28      MIN      MIN    -5.5   43.5   NaN   NaN      NaN    NaN    False        True       False              2              0                 False                0
# 12483   10/6/2019    2019           5    False      OAK         24         21      CHI      CHI    -6.5   39.5   NaN   NaN      NaN    NaN     True        True        True              1              3                 False                0
# 12484   10/6/2019    2019           5    False      PHI         31          6      NYJ      PHI   -14.0   43.0   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12485   10/6/2019    2019           5    False      PIT         23         26      BAL      BAL    -3.0   44.0   NaN   NaN      NaN    NaN    False        True       False              1              0                 False                0
# 12486   10/6/2019    2019           5    False      TEN          7         14      BUF      TEN    -3.0   39.5   NaN   NaN      NaN    NaN    False        True       False              1              0                  True                0
# 12487   10/6/2019    2019           5    False      WAS          7         33       NE       NE   -16.5   41.5   NaN   NaN      NaN    NaN    False       False        True              0              4                 False                0
# 12488   10/7/2019    2019           5    False       SF         31          3      CLE       SF    -4.5   48.0   NaN   NaN      NaN    NaN     True        True        True              3              1                 False                0
# 12489  10/10/2019    2019           6    False       NE         35         14      NYG       NE   -16.5   43.0   NaN   NaN      NaN    NaN     True        True       False              5              0                  True                0
# 12490  10/13/2019    2019           6    False      ARI         34         33      ATL      ATL    -3.0   52.0  72.0   0.0      NaN   DOME     True        True       False              1              0                 False                0
# 12491  10/13/2019    2019           6    False      BAL         23         17      CIN      BAL   -10.5   46.5   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12492  10/13/2019    2019           6    False      CLE         28         32      SEA      CLE    -1.0   45.5   NaN   NaN      NaN    NaN    False       False        True              0              2                 False                0
# 12493  10/13/2019    2019           6    False      DEN         16          0      TEN      DEN    -1.5   41.0   NaN   NaN      NaN    NaN     True        True       False              1              0                 False                0
# 12494  10/13/2019    2019           6    False      JAX          6         13       NO      JAX    -2.5   42.5   NaN   NaN      NaN    NaN    False       False        True              0              3                 False                0
# 12495  10/13/2019    2019           6    False       KC         24         31      HOU       KC    -3.5   54.5   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12496  10/13/2019    2019           6    False      LAC         17         24      PIT      LAC    -6.0   42.5   NaN   NaN      NaN    NaN    False       False       False              0              0                  True                0
# 12497  10/13/2019    2019           6    False      LAR          7         20       SF      LAR    -3.0   50.0   NaN   NaN      NaN    NaN    False       False        True              0              4                  True                0
# 12498  10/13/2019    2019           6    False      MIA         16         17      WAS      WAS    -5.5   42.5   NaN   NaN      NaN    NaN    False       False       False              0              0                  True                0
# 12499  10/13/2019    2019           6    False      MIN         38         20      PHI      MIN    -3.5   44.5   NaN   NaN      NaN    NaN     True        True        True              1              2                 False                0
# 12500  10/13/2019    2019           6    False      NYJ         24         22      DAL      DAL    -7.0   43.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12501  10/13/2019    2019           6    False       TB         26         37      CAR      CAR    -2.0   47.5   NaN   NaN      NaN    NaN    False       False        True              0              3                 False                1
# 12502  10/14/2019    2019           6    False       GB         23         22      DET       GB    -3.5   47.0   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12503  10/17/2019    2019           7    False      DEN          6         30       KC       KC    -3.0   49.5   NaN   NaN      NaN    NaN    False        True       False              2              0                 False                0
# 12504  10/20/2019    2019           7    False      ATL         10         37      LAR      LAR    -3.0   54.5  72.0   0.0      NaN   DOME    False       False       False              0              0                 False                0
# 12505  10/20/2019    2019           7    False      BUF         31         21      MIA      BUF   -17.0   42.5   NaN   NaN      NaN    NaN     True        True       False              1              0                 False                0
# 12506  10/20/2019    2019           7    False      CHI         25         36       NO      CHI    -4.0   37.0   NaN   NaN      NaN    NaN    False       False        True              0              4                 False                0
# 12507  10/20/2019    2019           7    False      CIN         17         27      JAX      JAX    -4.0   44.0   NaN   NaN      NaN    NaN    False       False       False              0              0                  True                0
# 12508  10/20/2019    2019           7    False      DAL         37         10      PHI      DAL    -3.0   50.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12509  10/20/2019    2019           7    False      DET         30         42      MIN      MIN    -2.5   43.5  72.0   0.0      NaN   DOME    False       False        True              0              2                 False                0
# 12510  10/20/2019    2019           7    False       GB         42         24      OAK       GB    -5.5   47.5   NaN   NaN      NaN    NaN     True        True        True              2              2                  True                0
# 12511  10/20/2019    2019           7    False      IND         30         23      HOU      IND    -1.0   46.5  72.0   0.0      NaN   DOME     True        True        True              1              2                 False                0
# 12512  10/20/2019    2019           7    False      NYG         21         27      ARI      NYG    -3.5   50.0   NaN   NaN      NaN    NaN    False       False        True              0              2                  True                0
# 12513  10/20/2019    2019           7    False      SEA         16         30      BAL      SEA    -3.0   48.5   NaN   NaN      NaN    NaN    False        True        True              3              2                 False                0
# 12514  10/20/2019    2019           7    False      TEN         23         20      LAC      TEN    -2.5   42.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12515  10/20/2019    2019           7    False      WAS          0          9       SF       SF   -10.0   39.0   NaN   NaN      NaN    NaN    False        True        True              1              5                  True                0
# 12516  10/21/2019    2019           7    False      NYJ          0         33       NE       NE   -10.0   43.0   NaN   NaN      NaN    NaN    False        True        True              1              6                 False                0
# 12517  10/24/2019    2019           8    False      MIN         19          9      WAS      MIN   -16.5   42.0   NaN   NaN      NaN    NaN     True        True       False              3              0                  True                0
# 12518  10/27/2019    2019           8    False      ATL         20         27      SEA      SEA    -7.5   48.5  72.0   0.0      NaN   DOME    False       False       False              0              0                 False                0
# 12519  10/27/2019    2019           8    False      BUF         13         31      PHI      BUF    -1.0   39.5   NaN   NaN      NaN    NaN    False        True       False              2              0                 False                0
# 12520  10/27/2019    2019           8    False      CHI         16         17      LAC      CHI    -3.5   41.0   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12521  10/27/2019    2019           8    False      DET         31         26      NYG      DET    -6.5   49.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12522  10/27/2019    2019           8    False      HOU         27         24      OAK      HOU    -6.0   52.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12523  10/27/2019    2019           8    False      IND         15         13      DEN      IND    -6.0   42.0  72.0   0.0      NaN   DOME     True        True       False              2              0                  True                0
# 12524  10/27/2019    2019           8    False      JAX         29         15      NYJ      JAX    -6.5   40.0   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12525  10/27/2019    2019           8    False       KC         24         31       GB       GB    -5.0   47.5   NaN   NaN      NaN    NaN    False        True        True              1              3                  True                0
# 12526  10/27/2019    2019           8    False      LAR         24         10      CIN      LAR   -12.0   48.5   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12527  10/27/2019    2019           8    False       NE         27         13      CLE       NE   -10.0   43.0   NaN   NaN      NaN    NaN     True        True       False              7              0                  True                0
# 12528  10/27/2019    2019           8    False       NO         31          9      ARI       NO   -12.5   48.0  72.0   0.0      NaN   DOME     True        True        True              5              3                  True                0
# 12529  10/27/2019    2019           8    False       SF         51         13      CAR       SF    -4.0   40.5   NaN   NaN      NaN    NaN     True        True        True              6              4                 False                0
# 12530  10/27/2019    2019           8    False      TEN         27         23       TB      TEN    -2.0   45.5   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12531  10/28/2019    2019           8    False      PIT         27         14      MIA      PIT   -14.0   44.0   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12532  10/31/2019    2019           9    False      ARI         25         28       SF       SF   -10.0   43.0  72.0   0.0      NaN   DOME    False       False        True              0              7                 False                0
# 12533   11/3/2019    2019           9    False      BAL         37         20       NE       NE    -3.0   44.5   NaN   NaN      NaN    NaN     True        True        True              3              8                 False                0
# 12534   11/3/2019    2019           9    False      BUF         24          9      WAS      BUF   -10.5   37.0   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12535   11/3/2019    2019           9    False      CAR         30         20      TEN      CAR    -3.5   43.0   NaN   NaN      NaN    NaN     True       False        True              0              2                 False                0
# 12536   11/3/2019    2019           9    False      DEN         24         19      CLE      CLE    -4.0   39.0   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12537   11/3/2019    2019           9    False      JAX          3         26      HOU      JAX    -1.0   46.0   NaN   NaN      NaN    NaN    False        True        True              2              1                 False                0
# 12538   11/3/2019    2019           9    False       KC         26         23      MIN      MIN    -5.5   45.5   NaN   NaN      NaN    NaN     True       False        True              0              4                  True                0
# 12539   11/3/2019    2019           9    False      LAC         26         11       GB       GB    -4.0   50.0   NaN   NaN      NaN    NaN     True        True        True              1              4                  True                0
# 12540   11/3/2019    2019           9    False      MIA         26         18      NYJ      NYJ    -3.0   42.5   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12541   11/3/2019    2019           9    False      OAK         31         24      DET      OAK    -2.5   51.0   NaN   NaN      NaN    NaN     True       False        True              0              1                 False                0
# 12542   11/3/2019    2019           9    False      PHI         22         14      CHI      PHI    -5.0   41.0   NaN   NaN      NaN    NaN     True        True       False              1              0                 False                0
# 12543   11/3/2019    2019           9    False      PIT         26         24      IND      PIT    -1.0   40.0   NaN   NaN      NaN    NaN     True        True        True              2              3                 False                0
# 12544   11/3/2019    2019           9    False      SEA         40         34       TB      SEA    -4.0   51.0   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12545   11/4/2019    2019           9    False      NYG         18         37      DAL      DAL    -6.5   48.5   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12546   11/7/2019    2019          10    False      OAK         26         24      LAC      LAC    -1.0   49.0   NaN   NaN      NaN    NaN     True        True        True              1              2                 False                0
# 12547  11/10/2019    2019          10    False      CHI         20         13      DET      CHI    -6.0   38.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12548  11/10/2019    2019          10    False      CIN         13         49      BAL      BAL   -10.5   44.0   NaN   NaN      NaN    NaN    False       False        True              0              4                 False                0
# 12549  11/10/2019    2019          10    False      CLE         19         16      BUF      CLE    -3.0   42.0   NaN   NaN      NaN    NaN     True       False        True              0              1                  True                0
# 12550  11/10/2019    2019          10    False      DAL         24         28      MIN      DAL    -3.0   48.0  72.0   0.0      NaN   DOME    False        True       False              2              0                  True                0
# 12551  11/10/2019    2019          10    False       GB         24         16      CAR       GB    -5.0   49.0   NaN   NaN      NaN    NaN     True       False        True              0              1                 False                0
# 12552  11/10/2019    2019          10    False      IND         12         16      MIA      IND   -11.0   44.0  72.0   0.0      NaN   DOME    False       False        True              0              1                  True                0
# 12553  11/10/2019    2019          10    False       NO          9         26      ATL       NO   -13.5   51.5  72.0   0.0      NaN   DOME    False        True       False              6              0                  True                0
# 12554  11/10/2019    2019          10    False      NYJ         34         27      NYG      NYG    -3.0   43.0   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12555  11/10/2019    2019          10    False      PIT         17         12      LAR      LAR    -4.5   43.5   NaN   NaN      NaN    NaN     True        True        True              3              2                 False                0
# 12556  11/10/2019    2019          10    False       TB         30         27      ARI       TB    -5.5   51.5   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12557  11/10/2019    2019          10    False      TEN         35         32       KC       KC    -6.0   49.0   NaN   NaN      NaN    NaN     True       False        True              0              1                 False                0
# 12558  11/11/2019    2019          10    False       SF         24         27      SEA       SF    -6.5   46.5   NaN   NaN      NaN    NaN    False        True        True              8              2                 False                0
# 12559  11/14/2019    2019          11    False      CLE         21          7      PIT      CLE    -3.0   41.5   NaN   NaN      NaN    NaN     True        True        True              1              4                 False                0
# 12560  11/17/2019    2019          11    False      BAL         41          7      HOU      BAL    -4.5   51.0   NaN   NaN      NaN    NaN     True        True        True              5              2                 False                0
# 12561  11/17/2019    2019          11    False      CAR          3         29      ATL      CAR    -4.0   49.0   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12562  11/17/2019    2019          11    False      DET         27         35      DAL      DAL    -7.0   46.5  72.0   0.0      NaN   DOME    False       False       False              0              0                 False                0
# 12563  11/17/2019    2019          11    False      IND         33         13      JAX      IND    -2.5   41.5  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12564  11/17/2019    2019          11    False      LAR         17          7      CHI      LAR    -5.5   40.0   NaN   NaN      NaN    NaN     True       False        True              0              1                  True                0
# 12565  11/17/2019    2019          11    False      MIA         20         37      BUF      BUF    -7.0   41.0   NaN   NaN      NaN    NaN    False        True       False              2              0                  True                0
# 12566  11/17/2019    2019          11    False      MIN         27         23      DEN      MIN   -10.0   40.0   NaN   NaN      NaN    NaN     True        True        True              1              1                  True                0
# 12567  11/17/2019    2019          11    False      OAK         17         10      CIN      OAK   -13.0   48.0   NaN   NaN      NaN    NaN     True        True       False              2              0                 False                0
# 12568  11/17/2019    2019          11    False      PHI         10         17       NE       NE    -4.5   45.0   NaN   NaN      NaN    NaN    False        True       False              2              0                 False                0
# 12569  11/17/2019    2019          11    False       SF         36         26      ARI       SF   -10.0   44.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                1
# 12570  11/17/2019    2019          11    False       TB         17         34       NO       NO    -5.0   50.5   NaN   NaN      NaN    NaN    False        True       False              1              0                 False                0
# 12571  11/17/2019    2019          11    False      WAS         17         34      NYJ      WAS    -2.0   37.5   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12572  11/18/2019    2019          11    False      LAC         17         24       KC       KC    -5.5   52.5   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12573  11/21/2019    2019          12    False      HOU         20         17      IND      HOU    -3.5   46.0  72.0   0.0      NaN   DOME     True       False        True              0              1                  True                0
# 12574  11/24/2019    2019          12    False      ATL         22         35       TB      ATL    -3.5   51.5  72.0   0.0      NaN   DOME    False        True       False              2              0                  True                0
# 12575  11/24/2019    2019          12    False      BUF         20          3      DEN      BUF    -3.5   37.0   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12576  11/24/2019    2019          12    False      CHI         19         14      NYG      CHI    -6.0   41.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12577  11/24/2019    2019          12    False      CIN         10         16      PIT      PIT    -6.5   37.0   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12578  11/24/2019    2019          12    False      CLE         41         24      MIA      CLE   -11.0   46.0   NaN   NaN      NaN    NaN     True        True       False              2              0                 False                0
# 12579  11/24/2019    2019          12    False       NE         13          9      DAL       NE    -5.5   44.5   NaN   NaN      NaN    NaN     True        True        True              1              1                  True                0
# 12580  11/24/2019    2019          12    False       NO         34         31      CAR       NO   -10.0   46.5  72.0   0.0      NaN   DOME     True        True       False              1              0                  True                0
# 12581  11/24/2019    2019          12    False      NYJ         34          3      OAK      OAK    -3.0   44.5   NaN   NaN      NaN    NaN     True        True        True              2              3                  True                0
# 12582  11/24/2019    2019          12    False      PHI          9         17      SEA      SEA    -2.0   45.5   NaN   NaN      NaN    NaN    False       False        True              0              3                 False                0
# 12583  11/24/2019    2019          12    False       SF         37          8       GB       SF    -3.0   48.0   NaN   NaN      NaN    NaN     True        True        True              1              1                 False                0
# 12584  11/24/2019    2019          12    False      TEN         42         20      JAX      TEN    -4.0   42.5   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                0
# 12585  11/24/2019    2019          12    False      WAS         19         16      DET      DET    -4.0   40.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12586  11/25/2019    2019          12    False      LAR          6         45      BAL      BAL    -3.5   47.0   NaN   NaN      NaN    NaN    False        True        True              1              6                  True                0
# 12587  11/28/2019    2019          13    False      ATL         18         26       NO       NO    -7.0   48.0  72.0   0.0      NaN   DOME    False       False        True              0              2                 False                1
# 12588  11/28/2019    2019          13    False      DAL         15         26      BUF      DAL    -6.5   46.5  72.0   0.0      NaN   DOME    False       False        True              0              2                  True                0
# 12589  11/28/2019    2019          13    False      DET         20         24      CHI      CHI    -5.5   37.0  72.0   0.0      NaN   DOME    False       False        True              0              1                 False                0
# 12590   12/1/2019    2019          13    False      ARI          7         34      LAR      LAR    -2.5   47.0  72.0   0.0      NaN   DOME    False       False       False              0              0                 False                0
# 12591   12/1/2019    2019          13    False      BAL         20         17       SF      BAL    -5.5   45.0   NaN   NaN      NaN    NaN     True        True        True              7              2                  True                0
# 12592   12/1/2019    2019          13    False      CAR         21         29      WAS      CAR   -10.5   38.5   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12593   12/1/2019    2019          13    False      CIN         22          6      NYJ      NYJ    -3.0   43.0   NaN   NaN      NaN    NaN     True       False        True              0              3                  True                0
# 12594   12/1/2019    2019          13    False      DEN         23         20      LAC      LAC    -4.5   38.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                1
# 12595   12/1/2019    2019          13    False      HOU         28         22       NE       NE    -3.0   47.0  72.0   0.0      NaN   DOME     True        True        True              1              2                 False                0
# 12596   12/1/2019    2019          13    False      IND         17         31      TEN      TEN    -1.0   41.5  72.0   0.0      NaN   DOME    False       False        True              0              2                  True                1
# 12597   12/1/2019    2019          13    False      JAX         11         28       TB       TB    -3.0   46.5   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12598   12/1/2019    2019          13    False       KC         40          9      OAK       KC   -10.5   49.5   NaN   NaN      NaN    NaN     True        True       False              1              0                  True                1
# 12599   12/1/2019    2019          13    False      MIA         37         31      PHI      PHI   -10.0   44.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12600   12/1/2019    2019          13    False      NYG         13         31       GB       GB    -6.5   43.5   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12601   12/1/2019    2019          13    False      PIT         20         13      CLE      CLE    -1.0   40.0   NaN   NaN      NaN    NaN     True        True        True              1              3                  True                0
# 12602   12/2/2019    2019          13    False      SEA         37         30      MIN      SEA    -2.5   48.5   NaN   NaN      NaN    NaN     True        True        True              4              2                  True                0
# 12603   12/5/2019    2019          14    False      CHI         31         24      DAL      DAL    -3.0   43.0   NaN   NaN      NaN    NaN     True        True       False              2              0                  True                0
# 12604   12/8/2019    2019          14    False      ARI         17         23      PIT      PIT    -2.5   43.5  72.0   0.0      NaN   DOME    False       False        True              0              2                 False                0
# 12605   12/8/2019    2019          14    False      ATL         40         20      CAR      ATL    -3.5   48.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                1
# 12606   12/8/2019    2019          14    False      BUF         17         24      BAL      BAL    -6.0   44.0   NaN   NaN      NaN    NaN    False        True        True              3              8                 False                0
# 12607   12/8/2019    2019          14    False      CLE         27         19      CIN      CLE    -6.5   43.5   NaN   NaN      NaN    NaN     True       False        True              0              1                  True                0
# 12608   12/8/2019    2019          14    False       GB         20         15      WAS       GB   -13.0   42.0   NaN   NaN      NaN    NaN     True        True        True              1              2                 False                0
# ...
# 12612   12/8/2019    2019          14    False      MIN         20          7      DET      MIN   -11.5   44.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                1
# 12613   12/8/2019    2019          14    False       NE         16         23       KC       NE    -3.0   48.5   NaN   NaN      NaN    NaN    False       False        True              0              2                 False                0
# 12614   12/8/2019    2019          14    False       NO         46         48       SF       NO    -1.5   45.0  72.0   0.0      NaN   DOME    False        True       False              3              0                  True                0
# 12615   12/8/2019    2019          14    False      NYJ         22         21      MIA      NYJ    -5.0   47.0   NaN   NaN      NaN    NaN     True       False        True              0              1                 False                0
# 12616   12/8/2019    2019          14    False      OAK         21         42      TEN      TEN    -2.5   47.0   NaN   NaN      NaN    NaN    False       False        True              0              3                 False                0
# 12617   12/8/2019    2019          14    False       TB         38         35      IND       TB    -3.0   46.5   NaN   NaN      NaN    NaN     True        True       False              2              0                 False                0
# 12618   12/9/2019    2019          14    False      PHI         23         17      NYG      PHI    -9.5   45.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12619  12/12/2019    2019          15    False      BAL         42         21      NYJ      BAL   -17.0   44.0   NaN   NaN      NaN    NaN     True        True        True              9              1                  True                0
# 12620  12/15/2019    2019          15    False      ARI         38         24      CLE      CLE    -3.0   49.0  72.0   0.0      NaN   DOME     True       False        True              0              1                 False                0
# 12621  12/15/2019    2019          15    False      CAR         24         30      SEA      SEA    -6.0   48.5   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12622  12/15/2019    2019          15    False      CIN         13         34       NE       NE   -10.5   41.5   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12623  12/15/2019    2019          15    False      DAL         44         21      LAR      LAR    -1.0   48.5  72.0   0.0      NaN   DOME     True       False        True              0              2                 False                0
# 12624  12/15/2019    2019          15    False      DET         17         38       TB       TB    -6.0   46.0  72.0   0.0      NaN   DOME    False       False        True              0              3                  True                0
# 12625  12/15/2019    2019          15    False       GB         21         13      CHI       GB    -4.5   41.0   NaN   NaN      NaN    NaN     True        True        True              2              3                 False                1
# 12626  12/15/2019    2019          15    False       KC         23          3      DEN       KC    -9.0   43.0   NaN   NaN      NaN    NaN     True        True        True              3              2                  True                1
# 12627  12/15/2019    2019          15    False      LAC         10         39      MIN      MIN    -1.0   45.0   NaN   NaN      NaN    NaN    False        True        True              1              1                  True                0
# 12628  12/15/2019    2019          15    False      NYG         36         20      MIA      NYG    -3.5   46.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12629  12/15/2019    2019          15    False      OAK         16         20      JAX      OAK    -6.5   46.0   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12630  12/15/2019    2019          15    False      PIT         10         17      BUF      PIT    -1.0   37.0   NaN   NaN      NaN    NaN    False        True       False              3              0                  True                0
# 12631  12/15/2019    2019          15    False       SF         22         29      ATL       SF   -10.0   49.5   NaN   NaN      NaN    NaN    False        True        True              1              1                 False                0
# 12632  12/15/2019    2019          15    False      TEN         21         24      HOU      TEN    -3.0   50.0   NaN   NaN      NaN    NaN    False        True       False              4              0                 False                0
# 12633  12/15/2019    2019          15    False      WAS         27         37      PHI      PHI    -6.5   38.5   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12634  12/16/2019    2019          15    False       NO         34          7      IND       NO    -8.5   49.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12635  12/21/2019    2019          16    False       NE         24         17      BUF       NE    -6.5   38.5   NaN   NaN      NaN    NaN     True        True        True              1              1                  True                1
# 12636  12/21/2019    2019          16    False       SF         34         31      LAR       SF    -7.0   45.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                1
# 12637  12/21/2019    2019          16    False       TB         20         23      HOU      HOU    -3.0   50.5   NaN   NaN      NaN    NaN    False        True        True              4              1                 False                0
# 12638  12/22/2019    2019          16    False      ATL         24         12      JAX      ATL    -7.0   48.0  72.0   0.0      NaN   DOME     True        True        True              2              1                  True                0
# 12639  12/22/2019    2019          16    False      CHI          3         26       KC       KC    -7.0   45.5   NaN   NaN      NaN    NaN    False       False        True              0              4                 False                0
# 12640  12/22/2019    2019          16    False      CLE         15         31      BAL      BAL   -10.0   49.0   NaN   NaN      NaN    NaN    False       False        True              0             10                 False                1
# 12641  12/22/2019    2019          16    False      DEN         27         17      DET      DEN    -7.5   40.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12642  12/22/2019    2019          16    False      IND         38          6      CAR      IND    -7.0   46.5  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12643  12/22/2019    2019          16    False      LAC         17         24      OAK      LAC    -7.5   45.0   NaN   NaN      NaN    NaN    False       False       False              0              0                  True                0
# 12644  12/22/2019    2019          16    False      MIA         38         35      CIN      CIN    -1.5   45.0   NaN   NaN      NaN    NaN     True       False       False              0              0                  True                0
# 12645  12/22/2019    2019          16    False      NYJ         16         10      PIT      PIT    -3.0   36.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12646  12/22/2019    2019          16    False      PHI         17          9      DAL      DAL    -2.0   46.5   NaN   NaN      NaN    NaN     True        True        True              2              1                 False                0
# 12647  12/22/2019    2019          16    False      SEA         13         27      ARI      SEA    -8.0   51.0   NaN   NaN      NaN    NaN    False        True        True              1              1                  True                1
# 12648  12/22/2019    2019          16    False      TEN         28         38       NO       NO    -3.0   49.0   NaN   NaN      NaN    NaN    False       False        True              0              1                 False                0
# 12649  12/22/2019    2019          16    False      WAS         35         41      NYG      NYG    -1.0   42.0   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12650  12/23/2019    2019          16    False      MIN         10         23       GB      MIN    -4.0   46.5   NaN   NaN      NaN    NaN    False        True        True              2              3                  True                0
# 12651  12/29/2019    2019          17    False      BAL         28         10      PIT      PIT    -1.0   35.0   NaN   NaN      NaN    NaN     True        True       False             11              0                  True                1
# 12652  12/29/2019    2019          17    False      BUF          6         13      NYJ      NYJ    -1.0   37.0   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                1
# 12653  12/29/2019    2019          17    False      CAR         10         42       NO       NO   -14.0   44.5   NaN   NaN      NaN    NaN    False       False        True              0              2                 False                0
# 12654  12/29/2019    2019          17    False      CIN         33         23      CLE      CLE    -2.5   43.5   NaN   NaN      NaN    NaN     True       False       False              0              0                 False                0
# 12655  12/29/2019    2019          17    False      DAL         47         16      WAS      DAL   -12.5   47.5  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                1
# 12656  12/29/2019    2019          17    False      DEN         16         15      OAK      DEN    -4.5   41.0   NaN   NaN      NaN    NaN     True        True        True              1              1                  True                0
# 12657  12/29/2019    2019          17    False      DET         20         23       GB       GB   -13.0   44.0  72.0   0.0      NaN   DOME    False       False        True              0              4                 False                0
# 12658  12/29/2019    2019          17    False      HOU         14         35      TEN      TEN   -10.0   43.0  72.0   0.0      NaN   DOME    False        True       False              2              0                  True                1
# 12659  12/29/2019    2019          17    False      JAX         38         20      IND      IND    -5.5   41.5   NaN   NaN      NaN    NaN     True       False        True              0              1                 False                0
# 12660  12/29/2019    2019          17    False       KC         31         21      LAC       KC    -9.5   46.0   NaN   NaN      NaN    NaN     True        True       False              5              0                  True                1
# 12661  12/29/2019    2019          17    False      LAR         31         24      ARI      LAR    -7.0   45.5   NaN   NaN      NaN    NaN     True       False        True              0              2                  True                1
# 12662  12/29/2019    2019          17    False      MIN         19         21      CHI      CHI    -4.5   36.0   NaN   NaN      NaN    NaN    False       False       False              0              0                 False                0
# 12663  12/29/2019    2019          17    False       NE         24         27      MIA       NE   -17.0   45.5   NaN   NaN      NaN    NaN    False        True        True              2              1                  True                1
# 12664  12/29/2019    2019          17    False      NYG         17         34      PHI      PHI    -3.5   44.5   NaN   NaN      NaN    NaN    False        True        True              2              3                 False                0
# 12665  12/29/2019    2019          17    False      SEA         21         26       SF       SF    -3.5   47.0   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                1
# 12666  12/29/2019    2019          17    False       TB         22         28      ATL       TB    -1.0   48.5   NaN   NaN      NaN    NaN    False       False        True              0              3                 False                1
# 12667    1/4/2020    2019    Wildcard     True      HOU         22         19      BUF      HOU    -2.5   43.0  72.0   0.0      NaN   DOME     True       False       False              0              0                  True                0
# 12668    1/4/2020    2019    Wildcard     True       NE         13         20      TEN       NE    -4.5   45.0   NaN   NaN      NaN    NaN    False       False        True              0              1                  True                0
# 12669    1/5/2020    2019    Wildcard     True       NO         20         26      MIN       NO    -7.5   49.5  72.0   0.0      NaN   DOME    False        True       False              3              0                  True                0
# 12670    1/5/2020    2019    Wildcard     True      PHI          9         17      SEA      PHI    -1.0   44.5   NaN   NaN      NaN    NaN    False        True       False              4              0                 False                0
# 12671   1/11/2020    2019    Division     True      BAL         12         28      TEN      BAL   -10.0   47.5   NaN   NaN      NaN    NaN    False        True        True             12              2                  True                0
# 12672   1/11/2020    2019    Division     True       SF         27         10      MIN       SF    -7.0   44.5   NaN   NaN      NaN    NaN     True        True        True              2              1                 False                0
# 12673   1/12/2020    2019    Division     True       GB         28         23      SEA       GB    -4.5   45.5   NaN   NaN      NaN    NaN     True        True        True              5              1                 False                0
# 12674   1/12/2020    2019    Division     True       KC         51         31      HOU       KC   -10.0   50.5   NaN   NaN      NaN    NaN     True        True        True              6              1                  True                0
# 12675   1/19/2020    2019  Conference     True       KC         35         24      TEN       KC    -7.0   51.0   NaN   NaN      NaN    NaN     True        True        True              7              3                  True                0
# 12676   1/19/2020    2019  Conference     True       SF         37         20       GB       SF    -8.0   46.5   NaN   NaN      NaN    NaN     True        True        True              3              6                 False                1
# 12677    2/2/2020    2019   Superbowl     True       KC         31         20       SF       KC    -1.5   53.0   NaN   NaN      NaN    NaN     True        True        True              8              4                  True                0

# %%
X_home_higher = results[['homeLastWin', 'awayLastWin', 'homeTeamRankedHigher', 'homeTeamWonLast']].values
clf = DecisionTreeClassifier(random_state = 14)
scores = cross_val_score(clf, X_home_higher, y_true, scoring = scorer)
print('Using whether the home team won last encounter - Accuracy: {0:.4f}'.format(np.mean(scores)))
# Out:
# Using whether the home team won last encounter - Accuracy: 0.6779

# %%
#my attempt at creating a spread column. not sure if it works yet. 

def home_spread (row):
    home_team = row['homeTeam']
    favorite = row['favorite']
    spread = row['spread']
    if home_team == favorite:
        return spread
    else: return spread*(-1)
    
results['homeSpread'] = results.apply(home_spread, axis=1)
print(results[['season', 'week', 'homeTeam', 'homeScore', 'awayScore', 'awayTeam', 'favorite', 'spread', 'total', 'homeWin', 'homeLastWin', 'awayLastWin']])
# Out:
#        season        week homeTeam  homeScore  awayScore awayTeam favorite  spread  total  homeWin homeLastWin awayLastWin
# 12411    2019           1      CHI          3         10       GB      CHI    -3.0   46.5    False           0           0
# 12412    2019           1      ARI         27         27      DET      DET    -3.0   45.5    False           0           0
# 12413    2019           1      CAR         27         30      LAR      LAR    -2.0   49.5    False           0           0
# 12414    2019           1      CLE         13         43      TEN      CLE    -5.5   44.0    False           0           0
# 12415    2019           1      DAL         35         17      NYG      DAL    -7.0   44.0     True           0           0
# 12416    2019           1      JAX         26         40       KC       KC    -3.5   49.0    False           0           0
# 12417    2019           1      LAC         30         24      IND      LAC    -6.0   44.5     True           0           0
# 12418    2019           1      MIA         10         59      BAL      BAL    -7.0   40.5    False           0           0
# 12419    2019           1      MIN         28         12      ATL      MIN    -3.5   47.0     True           0           0
# 12420    2019           1       NE         33          3      PIT       NE    -5.5   49.0     True           0           0
# 12421    2019           1      NYJ         16         17      BUF      NYJ    -2.5   41.0    False           0           0
# 12422    2019           1      PHI         32         27      WAS      PHI   -10.0   44.5     True           0           0
# 12423    2019           1      SEA         21         20      CIN      SEA    -9.0   44.0     True           0           0
# 12424    2019           1       TB         17         31       SF       TB    -1.0   51.0    False           0           0
# 12425    2019           1       NO         30         28      HOU       NO    -6.5   51.5     True           0           0
# 12426    2019           1      OAK         24         16      DEN      DEN    -3.0   42.5     True           0           0
# 12427    2019           2      CAR         14         20       TB      CAR    -6.5   48.0    False       False       False
# 12428    2019           2      ATL         24         20      PHI      PHI    -1.0   53.0     True       False        True
# 12429    2019           2      BAL         23         17      ARI      BAL   -13.0   45.5     True        True       False
# 12430    2019           2      CIN         17         41       SF      CIN    -1.0   46.0    False       False        True
# 12431    2019           2      DEN         14         16      CHI      CHI    -3.0   40.5    False       False       False
# 12432    2019           2      DET         13         10      LAC      LAC    -1.0   46.5     True        True        True
# 12433    2019           2       GB         21         16      MIN       GB    -3.0   43.0     True        True        True
# 12434    2019           2      HOU         13         12      JAX      HOU    -7.0   43.0     True       False       False
# 12435    2019           2      LAR         27          9       NO      LAR    -2.0   52.0     True        True        True
# 12436    2019           2      MIA          0         43       NE       NE   -18.0   48.5    False       False        True
# 12437    2019           2      NYG         14         28      BUF      BUF    -1.0   44.5    False       False        True
# 12438    2019           2      OAK         10         28       KC       KC    -7.0   53.0    False        True        True
# 12439    2019           2      PIT         26         28      SEA      PIT    -4.0   47.0    False       False        True
# 12440    2019           2      TEN         17         19      IND      TEN    -3.5   43.5    False        True       False
# 12441    2019           2      WAS         21         31      DAL      DAL    -6.0   46.0    False       False        True
# 12442    2019           2      NYJ          3         23      CLE      CLE    -6.5   45.0    False       False       False
# 12443    2019           3      JAX         20          7      TEN      TEN    -2.0   38.0     True       False       False
# 12444    2019           3      ARI         20         38      CAR      ARI    -2.5   45.5    False       False       False
# 12445    2019           3      BUF         21         17      CIN      BUF    -6.0   43.5     True        True       False
# 12446    2019           3      CLE         13         20      LAR      LAR    -4.0   48.0    False        True        True
# 12447    2019           3      DAL         31          6      MIA      DAL   -21.5   46.5     True        True       False
# 12448    2019           3       GB         27         16      DEN       GB    -7.0   41.5     True        True       False
# 12449    2019           3      IND         27         24      ATL      IND    -1.5   48.0     True        True        True
# 12450    2019           3       KC         33         28      BAL       KC    -5.0   52.0     True        True        True
# 12451    2019           3      LAC         20         27      HOU      LAC    -3.0   49.0    False       False        True
# 12452    2019           3      MIN         34         14      OAK      MIN    -9.0   43.5     True       False       False
# 12453    2019           3       NE         30         14      NYJ       NE   -21.0   43.0     True        True       False
# 12454    2019           3      PHI         24         27      DET      PHI    -4.0   45.0    False       False        True
# 12455    2019           3       SF         24         20      PIT       SF    -6.0   44.5     True        True       False
# 12456    2019           3      SEA         27         33       NO      SEA    -5.0   44.0    False        True       False
# 12457    2019           3       TB         31         32      NYG       TB    -5.0   48.0    False        True       False
# 12458    2019           3      WAS         15         31      CHI      CHI    -5.0   41.0    False       False        True
# 12459    2019           4       GB         27         34      PHI       GB    -3.5   46.5    False        True       False
# 12460    2019           4      ARI         10         27      SEA      SEA    -5.5   48.5    False       False       False
# 12461    2019           4      ATL         10         24      TEN      ATL    -3.5   46.5    False       False       False
# 12462    2019           4      BAL         25         40      CLE      BAL    -7.0   47.5    False       False       False
# 12463    2019           4      BUF         10         16       NE       NE    -7.0   41.5    False        True        True
# 12464    2019           4      CHI         16          6      MIN      CHI    -1.0   38.5     True        True        True
# 12465    2019           4      DEN         24         26      JAX      DEN    -2.5   37.5    False       False        True
# 12466    2019           4      DET         30         34       KC       KC    -7.0   54.5    False        True        True
# 12467    2019           4      HOU         10         16      CAR      HOU    -5.0   47.5    False        True        True
# 12468    2019           4      IND         24         31      OAK      IND    -6.0   46.5    False        True       False
# 12469    2019           4      LAR         40         55       TB      LAR    -9.0   48.5    False        True       False
# 12470    2019           4      MIA         10         30      LAC      LAC   -15.0   43.5    False       False       False
# 12471    2019           4       NO         12         10      DAL      DAL    -2.5   47.0     True        True        True
# 12472    2019           4      NYG         24          3      WAS      NYG    -3.0   48.0     True        True       False
# 12473    2019           4      PIT         27          3      CIN      PIT    -3.5   45.0     True       False       False
# 12474    2019           5      SEA         30         29      LAR      SEA    -1.5   48.5     True        True       False
# 12475    2019           5      CAR         34         27      JAX      CAR    -3.0   40.5     True        True        True
# 12476    2019           5      CIN         23         26      ARI      CIN    -3.0   46.5    False       False       False
# 12477    2019           5      DAL         24         34       GB      DAL    -3.0   46.5    False       False       False
# 12478    2019           5      HOU         53         32      ATL      HOU    -4.0   49.0     True       False       False
# 12479    2019           5       KC         13         19      IND       KC   -10.5   55.5    False        True       False
# 12480    2019           5      LAC         13         20      DEN      LAC    -4.5   45.5    False        True       False
# 12481    2019           5       NO         31         24       TB       NO    -3.0   46.5     True        True        True
# 12482    2019           5      NYG         10         28      MIN      MIN    -5.5   43.5    False        True       False
# 12483    2019           5      OAK         24         21      CHI      CHI    -6.5   39.5     True        True        True
# 12484    2019           5      PHI         31          6      NYJ      PHI   -14.0   43.0     True        True       False
# 12485    2019           5      PIT         23         26      BAL      BAL    -3.0   44.0    False        True       False
# 12486    2019           5      TEN          7         14      BUF      TEN    -3.0   39.5    False        True       False
# 12487    2019           5      WAS          7         33       NE       NE   -16.5   41.5    False       False        True
# 12488    2019           5       SF         31          3      CLE       SF    -4.5   48.0     True        True        True
# 12489    2019           6       NE         35         14      NYG       NE   -16.5   43.0     True        True       False
# 12490    2019           6      ARI         34         33      ATL      ATL    -3.0   52.0     True        True       False
# 12491    2019           6      BAL         23         17      CIN      BAL   -10.5   46.5     True        True       False
# 12492    2019           6      CLE         28         32      SEA      CLE    -1.0   45.5    False       False        True
# 12493    2019           6      DEN         16          0      TEN      DEN    -1.5   41.0     True        True       False
# 12494    2019           6      JAX          6         13       NO      JAX    -2.5   42.5    False       False        True
# 12495    2019           6       KC         24         31      HOU       KC    -3.5   54.5    False       False        True
# 12496    2019           6      LAC         17         24      PIT      LAC    -6.0   42.5    False       False       False
# 12497    2019           6      LAR          7         20       SF      LAR    -3.0   50.0    False       False        True
# 12498    2019           6      MIA         16         17      WAS      WAS    -5.5   42.5    False       False       False
# 12499    2019           6      MIN         38         20      PHI      MIN    -3.5   44.5     True        True        True
# 12500    2019           6      NYJ         24         22      DAL      DAL    -7.0   43.5     True       False       False
# 12501    2019           6       TB         26         37      CAR      CAR    -2.0   47.5    False       False        True
# 12502    2019           6       GB         23         22      DET       GB    -3.5   47.0     True        True       False
# 12503    2019           7      DEN          6         30       KC       KC    -3.0   49.5    False        True       False
# 12504    2019           7      ATL         10         37      LAR      LAR    -3.0   54.5    False       False       False
# 12505    2019           7      BUF         31         21      MIA      BUF   -17.0   42.5     True        True       False
# 12506    2019           7      CHI         25         36       NO      CHI    -4.0   37.0    False       False        True
# 12507    2019           7      CIN         17         27      JAX      JAX    -4.0   44.0    False       False       False
# 12508    2019           7      DAL         37         10      PHI      DAL    -3.0   50.0     True       False       False
# 12509    2019           7      DET         30         42      MIN      MIN    -2.5   43.5    False       False        True
# 12510    2019           7       GB         42         24      OAK       GB    -5.5   47.5     True        True        True
# 12511    2019           7      IND         30         23      HOU      IND    -1.0   46.5     True        True        True
# 12512    2019           7      NYG         21         27      ARI      NYG    -3.5   50.0    False       False        True
# 12513    2019           7      SEA         16         30      BAL      SEA    -3.0   48.5    False        True        True
# 12514    2019           7      TEN         23         20      LAC      TEN    -2.5   42.5     True       False       False
# 12515    2019           7      WAS          0          9       SF       SF   -10.0   39.0    False        True        True
# 12516    2019           7      NYJ          0         33       NE       NE   -10.0   43.0    False        True        True
# 12517    2019           8      MIN         19          9      WAS      MIN   -16.5   42.0     True        True       False
# 12518    2019           8      ATL         20         27      SEA      SEA    -7.5   48.5    False       False       False
# 12519    2019           8      BUF         13         31      PHI      BUF    -1.0   39.5    False        True       False
# 12520    2019           8      CHI         16         17      LAC      CHI    -3.5   41.0    False       False       False
# 12521    2019           8      DET         31         26      NYG      DET    -6.5   49.0     True       False       False
# 12522    2019           8      HOU         27         24      OAK      HOU    -6.0   52.0     True       False       False
# 12523    2019           8      IND         15         13      DEN      IND    -6.0   42.0     True        True       False
# 12524    2019           8      JAX         29         15      NYJ      JAX    -6.5   40.0     True        True       False
# 12525    2019           8       KC         24         31       GB       GB    -5.0   47.5    False        True        True
# 12526    2019           8      LAR         24         10      CIN      LAR   -12.0   48.5     True        True       False
# 12527    2019           8       NE         27         13      CLE       NE   -10.0   43.0     True        True       False
# 12528    2019           8       NO         31          9      ARI       NO   -12.5   48.0     True        True        True
# 12529    2019           8       SF         51         13      CAR       SF    -4.0   40.5     True        True        True
# 12530    2019           8      TEN         27         23       TB      TEN    -2.0   45.5     True        True       False
# 12531    2019           8      PIT         27         14      MIA      PIT   -14.0   44.0     True        True       False
# 12532    2019           9      ARI         25         28       SF       SF   -10.0   43.0    False       False        True
# 12533    2019           9      BAL         37         20       NE       NE    -3.0   44.5     True        True        True
# 12534    2019           9      BUF         24          9      WAS      BUF   -10.5   37.0     True       False       False
# 12535    2019           9      CAR         30         20      TEN      CAR    -3.5   43.0     True       False        True
# 12536    2019           9      DEN         24         19      CLE      CLE    -4.0   39.0     True       False       False
# 12537    2019           9      JAX          3         26      HOU      JAX    -1.0   46.0    False        True        True
# 12538    2019           9       KC         26         23      MIN      MIN    -5.5   45.5     True       False        True
# 12539    2019           9      LAC         26         11       GB       GB    -4.0   50.0     True        True        True
# 12540    2019           9      MIA         26         18      NYJ      NYJ    -3.0   42.5     True       False       False
# 12541    2019           9      OAK         31         24      DET      OAK    -2.5   51.0     True       False        True
# 12542    2019           9      PHI         22         14      CHI      PHI    -5.0   41.0     True        True       False
# 12543    2019           9      PIT         26         24      IND      PIT    -1.0   40.0     True        True        True
# 12544    2019           9      SEA         40         34       TB      SEA    -4.0   51.0     True        True       False
# 12545    2019           9      NYG         18         37      DAL      DAL    -6.5   48.5    False       False        True
# 12546    2019          10      OAK         26         24      LAC      LAC    -1.0   49.0     True        True        True
# 12547    2019          10      CHI         20         13      DET      CHI    -6.0   38.0     True       False       False
# 12548    2019          10      CIN         13         49      BAL      BAL   -10.5   44.0    False       False        True
# 12549    2019          10      CLE         19         16      BUF      CLE    -3.0   42.0     True       False        True
# 12550    2019          10      DAL         24         28      MIN      DAL    -3.0   48.0    False        True       False
# 12551    2019          10       GB         24         16      CAR       GB    -5.0   49.0     True       False        True
# 12552    2019          10      IND         12         16      MIA      IND   -11.0   44.0    False       False        True
# 12553    2019          10       NO          9         26      ATL       NO   -13.5   51.5    False        True       False
# 12554    2019          10      NYJ         34         27      NYG      NYG    -3.0   43.0     True       False       False
# 12555    2019          10      PIT         17         12      LAR      LAR    -4.5   43.5     True        True        True
# 12556    2019          10       TB         30         27      ARI       TB    -5.5   51.5     True       False       False
# 12557    2019          10      TEN         35         32       KC       KC    -6.0   49.0     True       False        True
# 12558    2019          10       SF         24         27      SEA       SF    -6.5   46.5    False        True        True
# 12559    2019          11      CLE         21          7      PIT      CLE    -3.0   41.5     True        True        True
# 12560    2019          11      BAL         41          7      HOU      BAL    -4.5   51.0     True        True        True
# 12561    2019          11      CAR          3         29      ATL      CAR    -4.0   49.0    False       False        True
# 12562    2019          11      DET         27         35      DAL      DAL    -7.0   46.5    False       False       False
# 12563    2019          11      IND         33         13      JAX      IND    -2.5   41.5     True       False       False
# 12564    2019          11      LAR         17          7      CHI      LAR    -5.5   40.0     True       False        True
# 12565    2019          11      MIA         20         37      BUF      BUF    -7.0   41.0    False        True       False
# 12566    2019          11      MIN         27         23      DEN      MIN   -10.0   40.0     True        True        True
# 12567    2019          11      OAK         17         10      CIN      OAK   -13.0   48.0     True        True       False
# 12568    2019          11      PHI         10         17       NE       NE    -4.5   45.0    False        True       False
# 12569    2019          11       SF         36         26      ARI       SF   -10.0   44.0     True       False       False
# 12570    2019          11       TB         17         34       NO       NO    -5.0   50.5    False        True       False
# 12571    2019          11      WAS         17         34      NYJ      WAS    -2.0   37.5    False       False        True
# 12572    2019          11      LAC         17         24       KC       KC    -5.5   52.5    False       False       False
# 12573    2019          12      HOU         20         17      IND      HOU    -3.5   46.0     True       False        True
# 12574    2019          12      ATL         22         35       TB      ATL    -3.5   51.5    False        True       False
# 12575    2019          12      BUF         20          3      DEN      BUF    -3.5   37.0     True        True       False
# 12576    2019          12      CHI         19         14      NYG      CHI    -6.0   41.0     True       False       False
# 12577    2019          12      CIN         10         16      PIT      PIT    -6.5   37.0    False       False       False
# 12578    2019          12      CLE         41         24      MIA      CLE   -11.0   46.0     True        True       False
# 12579    2019          12       NE         13          9      DAL       NE    -5.5   44.5     True        True        True
# 12580    2019          12       NO         34         31      CAR       NO   -10.0   46.5     True        True       False
# 12581    2019          12      NYJ         34          3      OAK      OAK    -3.0   44.5     True        True        True
# 12582    2019          12      PHI          9         17      SEA      SEA    -2.0   45.5    False       False        True
# 12583    2019          12       SF         37          8       GB       SF    -3.0   48.0     True        True        True
# 12584    2019          12      TEN         42         20      JAX      TEN    -4.0   42.5     True        True       False
# 12585    2019          12      WAS         19         16      DET      DET    -4.0   40.0     True       False       False
# 12586    2019          12      LAR          6         45      BAL      BAL    -3.5   47.0    False        True        True
# 12587    2019          13      ATL         18         26       NO       NO    -7.0   48.0    False       False        True
# 12588    2019          13      DAL         15         26      BUF      DAL    -6.5   46.5    False       False        True
# 12589    2019          13      DET         20         24      CHI      CHI    -5.5   37.0    False       False        True
# 12590    2019          13      ARI          7         34      LAR      LAR    -2.5   47.0    False       False       False
# 12591    2019          13      BAL         20         17       SF      BAL    -5.5   45.0     True        True        True
# 12592    2019          13      CAR         21         29      WAS      CAR   -10.5   38.5    False       False        True
# 12593    2019          13      CIN         22          6      NYJ      NYJ    -3.0   43.0     True       False        True
# 12594    2019          13      DEN         23         20      LAC      LAC    -4.5   38.5     True       False       False
# 12595    2019          13      HOU         28         22       NE       NE    -3.0   47.0     True        True        True
# 12596    2019          13      IND         17         31      TEN      TEN    -1.0   41.5    False       False        True
# 12597    2019          13      JAX         11         28       TB       TB    -3.0   46.5    False       False        True
# 12598    2019          13       KC         40          9      OAK       KC   -10.5   49.5     True        True       False
# 12599    2019          13      MIA         37         31      PHI      PHI   -10.0   44.5     True       False       False
# 12600    2019          13      NYG         13         31       GB       GB    -6.5   43.5    False       False       False
# 12601    2019          13      PIT         20         13      CLE      CLE    -1.0   40.0     True        True        True
# 12602    2019          13      SEA         37         30      MIN      SEA    -2.5   48.5     True        True        True
# 12603    2019          14      CHI         31         24      DAL      DAL    -3.0   43.0     True        True       False
# 12604    2019          14      ARI         17         23      PIT      PIT    -2.5   43.5    False       False        True
# 12605    2019          14      ATL         40         20      CAR      ATL    -3.5   48.0     True       False       False
# 12606    2019          14      BUF         17         24      BAL      BAL    -6.0   44.0    False        True        True
# 12607    2019          14      CLE         27         19      CIN      CLE    -6.5   43.5     True       False        True
# 12608    2019          14       GB         20         15      WAS       GB   -13.0   42.0     True        True        True
# 12609    2019          14      HOU         24         38      DEN      HOU    -8.0   42.5    False        True        True
# 12610    2019          14      JAX         10         45      LAC      LAC    -3.0   42.0    False       False       False
# 12611    2019          14      LAR         28         12      SEA      LAR    -1.0   47.5     True        True        True
# 12612    2019          14      MIN         20          7      DET      MIN   -11.5   44.0     True       False       False
# 12613    2019          14       NE         16         23       KC       NE    -3.0   48.5    False       False        True
# 12614    2019          14       NO         46         48       SF       NO    -1.5   45.0    False        True       False
# 12615    2019          14      NYJ         22         21      MIA      NYJ    -5.0   47.0     True       False        True
# 12616    2019          14      OAK         21         42      TEN      TEN    -2.5   47.0    False       False        True
# 12617    2019          14       TB         38         35      IND       TB    -3.0   46.5     True        True       False
# 12618    2019          14      PHI         23         17      NYG      PHI    -9.5   45.0     True       False       False
# 12619    2019          15      BAL         42         21      NYJ      BAL   -17.0   44.0     True        True        True
# 12620    2019          15      ARI         38         24      CLE      CLE    -3.0   49.0     True       False        True
# 12621    2019          15      CAR         24         30      SEA      SEA    -6.0   48.5    False       False       False
# 12622    2019          15      CIN         13         34       NE       NE   -10.5   41.5    False       False       False
# 12623    2019          15      DAL         44         21      LAR      LAR    -1.0   48.5     True       False        True
# 12624    2019          15      DET         17         38       TB       TB    -6.0   46.0    False       False        True
# 12625    2019          15       GB         21         13      CHI       GB    -4.5   41.0     True        True        True
# 12626    2019          15       KC         23          3      DEN       KC    -9.0   43.0     True        True        True
# 12627    2019          15      LAC         10         39      MIN      MIN    -1.0   45.0    False        True        True
# 12628    2019          15      NYG         36         20      MIA      NYG    -3.5   46.5     True       False       False
# 12629    2019          15      OAK         16         20      JAX      OAK    -6.5   46.0    False       False       False
# 12630    2019          15      PIT         10         17      BUF      PIT    -1.0   37.0    False        True       False
# 12631    2019          15       SF         22         29      ATL       SF   -10.0   49.5    False        True        True
# 12632    2019          15      TEN         21         24      HOU      TEN    -3.0   50.0    False        True       False
# 12633    2019          15      WAS         27         37      PHI      PHI    -6.5   38.5    False       False        True
# 12634    2019          15       NO         34          7      IND       NO    -8.5   49.0     True       False       False
# 12635    2019          16       NE         24         17      BUF       NE    -6.5   38.5     True        True        True
# 12636    2019          16       SF         34         31      LAR       SF    -7.0   45.5     True       False       False
# 12637    2019          16       TB         20         23      HOU      HOU    -3.0   50.5    False        True        True
# 12638    2019          16      ATL         24         12      JAX      ATL    -7.0   48.0     True        True        True
# 12639    2019          16      CHI          3         26       KC       KC    -7.0   45.5    False       False        True
# 12640    2019          16      CLE         15         31      BAL      BAL   -10.0   49.0    False       False        True
# 12641    2019          16      DEN         27         17      DET      DEN    -7.5   40.0     True       False       False
# 12642    2019          16      IND         38          6      CAR      IND    -7.0   46.5     True       False       False
# 12643    2019          16      LAC         17         24      OAK      LAC    -7.5   45.0    False       False       False
# 12644    2019          16      MIA         38         35      CIN      CIN    -1.5   45.0     True       False       False
# 12645    2019          16      NYJ         16         10      PIT      PIT    -3.0   36.5     True       False       False
# 12646    2019          16      PHI         17          9      DAL      DAL    -2.0   46.5     True        True        True
# 12647    2019          16      SEA         13         27      ARI      SEA    -8.0   51.0    False        True        True
# 12648    2019          16      TEN         28         38       NO       NO    -3.0   49.0    False       False        True
# 12649    2019          16      WAS         35         41      NYG      NYG    -1.0   42.0    False       False        True
# 12650    2019          16      MIN         10         23       GB      MIN    -4.0   46.5    False        True        True
# 12651    2019          17      BAL         28         10      PIT      PIT    -1.0   35.0     True        True       False
# 12652    2019          17      BUF          6         13      NYJ      NYJ    -1.0   37.0    False       False        True
# 12653    2019          17      CAR         10         42       NO       NO   -14.0   44.5    False       False        True
# 12654    2019          17      CIN         33         23      CLE      CLE    -2.5   43.5     True       False       False
# 12655    2019          17      DAL         47         16      WAS      DAL   -12.5   47.5     True       False       False
# 12656    2019          17      DEN         16         15      OAK      DEN    -4.5   41.0     True        True        True
# 12657    2019          17      DET         20         23       GB       GB   -13.0   44.0    False       False        True
# 12658    2019          17      HOU         14         35      TEN      TEN   -10.0   43.0    False        True       False
# 12659    2019          17      JAX         38         20      IND      IND    -5.5   41.5     True       False        True
# 12660    2019          17       KC         31         21      LAC       KC    -9.5   46.0     True        True       False
# 12661    2019          17      LAR         31         24      ARI      LAR    -7.0   45.5     True       False        True
# 12662    2019          17      MIN         19         21      CHI      CHI    -4.5   36.0    False       False       False
# 12663    2019          17       NE         24         27      MIA       NE   -17.0   45.5    False        True        True
# 12664    2019          17      NYG         17         34      PHI      PHI    -3.5   44.5    False        True        True
# 12665    2019          17      SEA         21         26       SF       SF    -3.5   47.0    False       False        True
# 12666    2019          17       TB         22         28      ATL       TB    -1.0   48.5    False       False        True
# 12667    2019    Wildcard      HOU         22         19      BUF      HOU    -2.5   43.0     True       False       False
# 12668    2019    Wildcard       NE         13         20      TEN       NE    -4.5   45.0    False       False        True
# 12669    2019    Wildcard       NO         20         26      MIN       NO    -7.5   49.5    False        True       False
# 12670    2019    Wildcard      PHI          9         17      SEA      PHI    -1.0   44.5    False        True       False
# 12671    2019    Division      BAL         12         28      TEN      BAL   -10.0   47.5    False        True        True
# 12672    2019    Division       SF         27         10      MIN       SF    -7.0   44.5     True        True        True
# 12673    2019    Division       GB         28         23      SEA       GB    -4.5   45.5     True        True        True
# 12674    2019    Division       KC         51         31      HOU       KC   -10.0   50.5     True        True        True
# 12675    2019  Conference       KC         35         24      TEN       KC    -7.0   51.0     True        True        True
# 12676    2019  Conference       SF         37         20       GB       SF    -8.0   46.5     True        True        True
# 12677    2019   Superbowl       KC         31         20       SF       KC    -1.5   53.0     True        True        True

# %%
def homeFav (row):
    home_spread = row['homeSpread']
    if home_spread < 0:
        return 1
    else:
        return 0

results['homeFav'] = results.apply(homeFav, axis =1)

# %%
X_homeFav = results[['homeFav']].values
scores = cross_val_score(clf, X_homeFav, y_true, scoring = scorer, cv = 4)
print('Using the favorite - F1: {0:.4f}'.format(np.mean(scores)))
# Out:
# Using the favorite - F1: 0.6410

# %%
results.to_csv("Z:\\Coding\\Myproj\\NFL\\Data\\resultsTest.csv")
